# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# VADER helps us to handle negation, emoticons, slang, abbreviations, and punctuation (like exclamation marks) that enhance sentiment. It also accounts for intensity modifiers (like "very" or "extremely") that amplify the sentiment of a word and can handle both positive and negative sentiments in a text, allowing for more accurate sentiment analysis. Additionally, VADER is optimized for analyzing informal text, making it particularly effective for use on social media platforms and other user-generated content.

# %%
import pandas as pd
ow2_5topics = pd.read_csv('./topic_modelling_BERTopic.csv')

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()
analyzer.lexicon["lazy"] = -3.8

domain_words = {
    "unplayable": -4.0,
    "10/10": 2,
    "bad devs":-4.0,
    "FIX AUDIO": -4.0,
    "trash" : -4.0,
    "this game gets worse and worse" : -4.0,
     "super inconsistent" : -4.0,
    "Best battle royale game": 4,
    "Probably the most fun i've ever had out of a battle royale": 4,
    "best battle royale games":4,
    "pog":3.8,
    "gem":4,
    "Despite all bugs and glitches":0,
    "Dogshit":-4.0,
    "bugs":-4.0,
}

analyzer.lexicon.update(domain_words)

vader_lexicon = analyzer.lexicon

for word, score in list(vader_lexicon.items())[:100000]:  
    print(f"Word: {word}, Sentiment Score: {score}")
# Out:
# Word: $:, Sentiment Score: -1.5
# Word: %), Sentiment Score: -0.4
# Word: %-), Sentiment Score: -1.5
# Word: &-:, Sentiment Score: -0.4
# Word: &:, Sentiment Score: -0.7
# Word: ( '}{' ), Sentiment Score: 1.6
# Word: (%, Sentiment Score: -0.9
# Word: ('-:, Sentiment Score: 2.2
# Word: (':, Sentiment Score: 2.3
# Word: ((-:, Sentiment Score: 2.1
# Word: (*, Sentiment Score: 1.1
# Word: (-%, Sentiment Score: -0.7
# Word: (-*, Sentiment Score: 1.3
# Word: (-:, Sentiment Score: 1.6
# Word: (-:0, Sentiment Score: 2.8
# Word: (-:<, Sentiment Score: -0.4
# Word: (-:o, Sentiment Score: 1.5
# Word: (-:O, Sentiment Score: 1.5
# Word: (-:{, Sentiment Score: -0.1
# Word: (-:|>*, Sentiment Score: 1.9
# Word: (-;, Sentiment Score: 1.3
# Word: (-;|, Sentiment Score: 2.1
# Word: (8, Sentiment Score: 2.6
# Word: (:, Sentiment Score: 2.2
# Word: (:0, Sentiment Score: 2.4
# Word: (:<, Sentiment Score: -0.2
# Word: (:o, Sentiment Score: 2.5
# Word: (:O, Sentiment Score: 2.5
# Word: (;, Sentiment Score: 1.1
# Word: (;<, Sentiment Score: 0.3
# Word: (=, Sentiment Score: 2.2
# Word: (?:, Sentiment Score: 2.1
# Word: (^:, Sentiment Score: 1.5
# Word: (^;, Sentiment Score: 1.5
# Word: (^;0, Sentiment Score: 2.0
# Word: (^;o, Sentiment Score: 1.9
# Word: (o:, Sentiment Score: 1.6
# Word: )':, Sentiment Score: -2.0
# Word: )-':, Sentiment Score: -2.1
# Word: )-:, Sentiment Score: -2.1
# Word: )-:<, Sentiment Score: -2.2
# Word: )-:{, Sentiment Score: -2.1
# Word: ):, Sentiment Score: -1.8
# Word: ):<, Sentiment Score: -1.9
# Word: ):{, Sentiment Score: -2.3
# Word: );<, Sentiment Score: -2.6
# Word: *), Sentiment Score: 0.6
# Word: *-), Sentiment Score: 0.3
# Word: *-:, Sentiment Score: 2.1
# Word: *-;, Sentiment Score: 2.4
# Word: *:, Sentiment Score: 1.9
# Word: *<|:-), Sentiment Score: 1.6
# Word: *\0/*, Sentiment Score: 2.3
# Word: *^:, Sentiment Score: 1.6
# Word: ,-:, Sentiment Score: 1.2
# Word: ---'-;-{@, Sentiment Score: 2.3
# Word: --<--<@, Sentiment Score: 2.2
# Word: .-:, Sentiment Score: -1.2
# Word: ..###-:, Sentiment Score: -1.7
# Word: ..###:, Sentiment Score: -1.9
# Word: /-:, Sentiment Score: -1.3
# Word: /:, Sentiment Score: -1.3
# Word: /:<, Sentiment Score: -1.4
# Word: /=, Sentiment Score: -0.9
# Word: /^:, Sentiment Score: -1.0
# Word: /o:, Sentiment Score: -1.4
# Word: 0-8, Sentiment Score: 0.1
# Word: 0-|, Sentiment Score: -1.2
# Word: 0:), Sentiment Score: 1.9
# Word: 0:-), Sentiment Score: 1.4
# Word: 0:-3, Sentiment Score: 1.5
# Word: 0:03, Sentiment Score: 1.9
# Word: 0;^), Sentiment Score: 1.6
# Word: 0_o, Sentiment Score: -0.3
# Word: 10q, Sentiment Score: 2.1
# Word: 1337, Sentiment Score: 2.1
# Word: 143, Sentiment Score: 3.2
# Word: 1432, Sentiment Score: 2.6
# Word: 14aa41, Sentiment Score: 2.4
# Word: 182, Sentiment Score: -2.9
# Word: 187, Sentiment Score: -3.1
# Word: 2g2b4g, Sentiment Score: 2.8
# Word: 2g2bt, Sentiment Score: -0.1
# Word: 2qt, Sentiment Score: 2.1
# Word: 3:(, Sentiment Score: -2.2
# Word: 3:), Sentiment Score: 0.5
# Word: 3:-(, Sentiment Score: -2.3
# Word: 3:-), Sentiment Score: -1.4
# Word: 4col, Sentiment Score: -2.2
# Word: 4q, Sentiment Score: -3.1
# Word: 5fs, Sentiment Score: 1.5
# Word: 8), Sentiment Score: 1.9
# Word: 8-d, Sentiment Score: 1.7
# Word: 8-o, Sentiment Score: -0.3
# Word: 86, Sentiment Score: -1.6
# Word: 8d, Sentiment Score: 2.9
# Word: :###.., Sentiment Score: -2.4
# Word: :$, Sentiment Score: -0.2
# Word: :&, Sentiment Score: -0.6
# Word: :'(, Sentiment Score: -2.2
# Word: :'), Sentiment Score: 2.3
# Word: :'-(, Sentiment Score: -2.4
# Word: :'-), Sentiment Score: 2.7
# Word: :(, Sentiment Score: -1.9
# Word: :), Sentiment Score: 2.0
# Word: :*, Sentiment Score: 2.5
# Word: :-###.., Sentiment Score: -2.5
# Word: :-&, Sentiment Score: -0.5
# Word: :-(, Sentiment Score: -1.5
# Word: :-), Sentiment Score: 1.3
# Word: :-)), Sentiment Score: 2.8
# Word: :-*, Sentiment Score: 1.7
# Word: :-,, Sentiment Score: 1.1
# Word: :-., Sentiment Score: -0.9
# Word: :-/, Sentiment Score: -1.2
# Word: :-<, Sentiment Score: -1.5
# Word: :-d, Sentiment Score: 2.3
# Word: :-D, Sentiment Score: 2.3
# Word: :-o, Sentiment Score: 0.1
# Word: :-p, Sentiment Score: 1.5
# Word: :-[, Sentiment Score: -1.6
# Word: :-\, Sentiment Score: -0.9
# Word: :-c, Sentiment Score: -1.3
# Word: :-|, Sentiment Score: -0.7
# Word: :-||, Sentiment Score: -2.5
# Word: :-Þ, Sentiment Score: 0.9
# Word: :/, Sentiment Score: -1.4
# Word: :3, Sentiment Score: 2.3
# Word: :<, Sentiment Score: -2.1
# Word: :>, Sentiment Score: 2.1
# Word: :?), Sentiment Score: 1.3
# Word: :?c, Sentiment Score: -1.6
# Word: :@, Sentiment Score: -2.5
# Word: :d, Sentiment Score: 2.3
# Word: :D, Sentiment Score: 2.3
# Word: :l, Sentiment Score: -1.7
# Word: :o, Sentiment Score: -0.4
# Word: :p, Sentiment Score: 1.0
# Word: :s, Sentiment Score: -1.2
# Word: :[, Sentiment Score: -2.0
# Word: :\, Sentiment Score: -1.3
# Word: :], Sentiment Score: 2.2
# Word: :^), Sentiment Score: 2.1
# Word: :^*, Sentiment Score: 2.6
# Word: :^/, Sentiment Score: -1.2
# Word: :^\, Sentiment Score: -1.0
# Word: :^|, Sentiment Score: -1.0
# Word: :c, Sentiment Score: -2.1
# Word: :c), Sentiment Score: 2.0
# Word: :o), Sentiment Score: 2.1
# Word: :o/, Sentiment Score: -1.4
# Word: :o\, Sentiment Score: -1.1
# Word: :o|, Sentiment Score: -0.6
# Word: :P, Sentiment Score: 1.4
# Word: :{, Sentiment Score: -1.9
# Word: :|, Sentiment Score: -0.4
# Word: :}, Sentiment Score: 2.1
# Word: :Þ, Sentiment Score: 1.1
# Word: ;), Sentiment Score: 0.9
# Word: ;-), Sentiment Score: 1.0
# Word: ;-*, Sentiment Score: 2.2
# Word: ;-], Sentiment Score: 0.7
# Word: ;d, Sentiment Score: 0.8
# Word: ;D, Sentiment Score: 0.8
# Word: ;], Sentiment Score: 0.6
# Word: ;^), Sentiment Score: 1.4
# Word: </3, Sentiment Score: -3.0
# Word: <3, Sentiment Score: 1.9
# Word: <:, Sentiment Score: 2.1
# Word: <:-|, Sentiment Score: -1.4
# Word: =), Sentiment Score: 2.2
# Word: =-3, Sentiment Score: 2.0
# Word: =-d, Sentiment Score: 2.4
# Word: =-D, Sentiment Score: 2.4
# Word: =/, Sentiment Score: -1.4
# Word: =3, Sentiment Score: 2.1
# Word: =d, Sentiment Score: 2.3
# Word: =D, Sentiment Score: 2.3
# Word: =l, Sentiment Score: -1.2
# Word: =\, Sentiment Score: -1.2
# Word: =], Sentiment Score: 1.6
# Word: =p, Sentiment Score: 1.3
# Word: =|, Sentiment Score: -0.8
# Word: >-:, Sentiment Score: -2.0
# Word: >.<, Sentiment Score: -1.3
# Word: >:, Sentiment Score: -2.1
# Word: >:(, Sentiment Score: -2.7
# Word: >:), Sentiment Score: 0.4
# Word: >:-(, Sentiment Score: -2.7
# Word: >:-), Sentiment Score: -0.4
# Word: >:/, Sentiment Score: -1.6
# Word: >:o, Sentiment Score: -1.2
# Word: >:p, Sentiment Score: 1.0
# Word: >:[, Sentiment Score: -2.1
# Word: >:\, Sentiment Score: -1.7
# Word: >;(, Sentiment Score: -2.9
# Word: >;), Sentiment Score: 0.1
# Word: >_>^, Sentiment Score: 2.1
# Word: @:, Sentiment Score: -2.1
# Word: @>-->--, Sentiment Score: 2.1
# Word: @}-;-'---, Sentiment Score: 2.2
# Word: aas, Sentiment Score: 2.5
# Word: aayf, Sentiment Score: 2.7
# Word: afu, Sentiment Score: -2.9
# Word: alol, Sentiment Score: 2.8
# Word: ambw, Sentiment Score: 2.9
# Word: aml, Sentiment Score: 3.4
# Word: atab, Sentiment Score: -1.9
# Word: awol, Sentiment Score: -1.3
# Word: ayc, Sentiment Score: 0.2
# Word: ayor, Sentiment Score: -1.2
# Word: aug-00, Sentiment Score: 0.3
# Word: bfd, Sentiment Score: -2.7
# Word: bfe, Sentiment Score: -2.6
# Word: bff, Sentiment Score: 2.9
# Word: bffn, Sentiment Score: 1.0
# Word: bl, Sentiment Score: 2.3
# Word: bsod, Sentiment Score: -2.2
# Word: btd, Sentiment Score: -2.1
# Word: btdt, Sentiment Score: -0.1
# Word: bz, Sentiment Score: 0.4
# Word: b^d, Sentiment Score: 2.6
# Word: cwot, Sentiment Score: -2.3
# Word: d-':, Sentiment Score: -2.5
# Word: d8, Sentiment Score: -3.2
# Word: d:, Sentiment Score: 1.2
# Word: d:<, Sentiment Score: -3.2
# Word: d;, Sentiment Score: -2.9
# Word: d=, Sentiment Score: 1.5
# Word: doa, Sentiment Score: -2.3
# Word: dx, Sentiment Score: -3.0
# Word: ez, Sentiment Score: 1.5
# Word: fav, Sentiment Score: 2.0
# Word: fcol, Sentiment Score: -1.8
# Word: ff, Sentiment Score: 1.8
# Word: ffs, Sentiment Score: -2.8
# Word: fkm, Sentiment Score: -2.4
# Word: foaf, Sentiment Score: 1.8
# Word: ftw, Sentiment Score: 2.0
# Word: fu, Sentiment Score: -3.7
# Word: fubar, Sentiment Score: -3.0
# Word: fwb, Sentiment Score: 2.5
# Word: fyi, Sentiment Score: 0.8
# Word: fysa, Sentiment Score: 0.4
# Word: g1, Sentiment Score: 1.4
# Word: gg, Sentiment Score: 1.2
# Word: gga, Sentiment Score: 1.7
# Word: gigo, Sentiment Score: -0.6
# Word: gj, Sentiment Score: 2.0
# Word: gl, Sentiment Score: 1.3
# Word: gla, Sentiment Score: 2.5
# Word: gn, Sentiment Score: 1.2
# Word: gr8, Sentiment Score: 2.7
# Word: grrr, Sentiment Score: -0.4
# Word: gt, Sentiment Score: 1.1
# Word: h&k, Sentiment Score: 2.3
# Word: hagd, Sentiment Score: 2.2
# Word: hagn, Sentiment Score: 2.2
# Word: hago, Sentiment Score: 1.2
# Word: hak, Sentiment Score: 1.9
# Word: hand, Sentiment Score: 2.2
# Word: heart, Sentiment Score: 3.2
# Word: hearts, Sentiment Score: 3.3
# Word: hho1/2k, Sentiment Score: 1.4
# Word: hhoj, Sentiment Score: 2.0
# Word: hhok, Sentiment Score: 0.9
# Word: hugz, Sentiment Score: 2.0
# Word: hi5, Sentiment Score: 1.9
# Word: idk, Sentiment Score: -0.4
# Word: ijs, Sentiment Score: 0.7
# Word: ilu, Sentiment Score: 3.4
# Word: iluaaf, Sentiment Score: 2.7
# Word: ily, Sentiment Score: 3.4
# Word: ily2, Sentiment Score: 2.6
# Word: iou, Sentiment Score: 0.7
# Word: iyq, Sentiment Score: 2.3
# Word: j/j, Sentiment Score: 2.0
# Word: j/k, Sentiment Score: 1.6
# Word: j/p, Sentiment Score: 1.4
# Word: j/t, Sentiment Score: -0.2
# Word: j/w, Sentiment Score: 1.0
# Word: j4f, Sentiment Score: 1.4
# Word: j4g, Sentiment Score: 1.7
# Word: jho, Sentiment Score: 0.8
# Word: jhomf, Sentiment Score: 1.0
# Word: jj, Sentiment Score: 1.0
# Word: jk, Sentiment Score: 0.9
# Word: jp, Sentiment Score: 0.8
# Word: jt, Sentiment Score: 0.9
# Word: jw, Sentiment Score: 1.6
# Word: jealz, Sentiment Score: -1.2
# Word: k4y, Sentiment Score: 2.3
# Word: kfy, Sentiment Score: 2.3
# Word: kia, Sentiment Score: -3.2
# Word: kk, Sentiment Score: 1.5
# Word: kmuf, Sentiment Score: 2.2
# Word: l, Sentiment Score: 2.0
# Word: l&r, Sentiment Score: 2.2
# Word: laoj, Sentiment Score: 1.3
# Word: lmao, Sentiment Score: 2.9
# Word: lmbao, Sentiment Score: 1.8
# Word: lmfao, Sentiment Score: 2.5
# Word: lmso, Sentiment Score: 2.7
# Word: lol, Sentiment Score: 1.8
# Word: lolz, Sentiment Score: 2.7
# Word: lts, Sentiment Score: 1.6
# Word: ly, Sentiment Score: 2.6
# Word: ly4e, Sentiment Score: 2.7
# Word: lya, Sentiment Score: 3.3
# Word: lyb, Sentiment Score: 3.0
# Word: lyl, Sentiment Score: 3.1
# Word: lylab, Sentiment Score: 2.7
# Word: lylas, Sentiment Score: 2.6
# Word: lylb, Sentiment Score: 1.6
# Word: m8, Sentiment Score: 1.4
# Word: mia, Sentiment Score: -1.2
# Word: mml, Sentiment Score: 2.0
# Word: mofo, Sentiment Score: -2.4
# Word: muah, Sentiment Score: 2.3
# Word: mubar, Sentiment Score: -1.0
# Word: musm, Sentiment Score: 0.9
# Word: mwah, Sentiment Score: 2.5
# Word: n1, Sentiment Score: 1.9
# Word: nbd, Sentiment Score: 1.3
# Word: nbif, Sentiment Score: -0.5
# Word: nfc, Sentiment Score: -2.7
# Word: nfw, Sentiment Score: -2.4
# Word: nh, Sentiment Score: 2.2
# Word: nimby, Sentiment Score: -0.8
# Word: nimjd, Sentiment Score: -0.7
# Word: nimq, Sentiment Score: -0.2
# Word: nimy, Sentiment Score: -1.4
# Word: nitl, Sentiment Score: -1.5
# Word: nme, Sentiment Score: -2.1
# Word: noyb, Sentiment Score: -0.7
# Word: np, Sentiment Score: 1.4
# Word: ntmu, Sentiment Score: 1.4
# Word: o-8, Sentiment Score: -0.5
# Word: o-:, Sentiment Score: -0.3
# Word: o-|, Sentiment Score: -1.1
# Word: o.o, Sentiment Score: -0.8
# Word: O.o, Sentiment Score: -0.6
# Word: o.O, Sentiment Score: -0.6
# Word: o:, Sentiment Score: -0.2
# Word: o:), Sentiment Score: 1.5
# Word: o:-), Sentiment Score: 2.0
# Word: o:-3, Sentiment Score: 2.2
# Word: o:3, Sentiment Score: 2.3
# Word: o:<, Sentiment Score: -0.3
# Word: o;^), Sentiment Score: 1.6
# Word: ok, Sentiment Score: 1.2
# Word: o_o, Sentiment Score: -0.5
# Word: O_o, Sentiment Score: -0.5
# Word: o_O, Sentiment Score: -0.5
# Word: pita, Sentiment Score: -2.4
# Word: pls, Sentiment Score: 0.3
# Word: plz, Sentiment Score: 0.3
# Word: pmbi, Sentiment Score: 0.8
# Word: pmfji, Sentiment Score: 0.3
# Word: pmji, Sentiment Score: 0.7
# Word: po, Sentiment Score: -2.6
# Word: ptl, Sentiment Score: 2.6
# Word: pu, Sentiment Score: -1.1
# Word: qq, Sentiment Score: -2.2
# Word: qt, Sentiment Score: 1.8
# Word: r&r, Sentiment Score: 2.4
# Word: rofl, Sentiment Score: 2.7
# Word: roflmao, Sentiment Score: 2.5
# Word: rotfl, Sentiment Score: 2.6
# Word: rotflmao, Sentiment Score: 2.8
# Word: rotflmfao, Sentiment Score: 2.5
# Word: rotflol, Sentiment Score: 3.0
# Word: rotgl, Sentiment Score: 2.9
# Word: rotglmao, Sentiment Score: 1.8
# Word: s:, Sentiment Score: -1.1
# Word: sapfu, Sentiment Score: -1.1
# Word: sete, Sentiment Score: 2.8
# Word: sfete, Sentiment Score: 2.7
# Word: sgtm, Sentiment Score: 2.4
# Word: slap, Sentiment Score: 0.6
# Word: slaw, Sentiment Score: 2.1
# Word: smh, Sentiment Score: -1.3
# Word: snafu, Sentiment Score: -2.5
# Word: sob, Sentiment Score: -1.0
# Word: swak, Sentiment Score: 2.3
# Word: tgif, Sentiment Score: 2.3
# Word: thks, Sentiment Score: 1.4
# Word: thx, Sentiment Score: 1.5
# Word: tia, Sentiment Score: 2.3
# Word: tmi, Sentiment Score: -0.3
# Word: tnx, Sentiment Score: 1.1
# Word: true, Sentiment Score: 1.8
# Word: tx, Sentiment Score: 1.5
# Word: txs, Sentiment Score: 1.1
# Word: ty, Sentiment Score: 1.6
# Word: tyvm, Sentiment Score: 2.5
# Word: urw, Sentiment Score: 1.9
# Word: vbg, Sentiment Score: 2.1
# Word: vbs, Sentiment Score: 3.1
# Word: vip, Sentiment Score: 2.3
# Word: vwd, Sentiment Score: 2.6
# Word: vwp, Sentiment Score: 2.1
# Word: wag, Sentiment Score: -0.2
# Word: wd, Sentiment Score: 2.7
# Word: wilco, Sentiment Score: 0.9
# Word: wp, Sentiment Score: 1.0
# Word: wtf, Sentiment Score: -2.8
# Word: wtg, Sentiment Score: 2.1
# Word: wth, Sentiment Score: -2.4
# Word: x-d, Sentiment Score: 2.6
# Word: x-p, Sentiment Score: 1.7
# Word: xd, Sentiment Score: 2.8
# Word: xlnt, Sentiment Score: 3.0
# Word: xoxo, Sentiment Score: 3.0
# Word: xoxozzz, Sentiment Score: 2.3
# Word: xp, Sentiment Score: 1.6
# Word: xqzt, Sentiment Score: 1.6
# Word: xtc, Sentiment Score: 0.8
# Word: yolo, Sentiment Score: 1.1
# Word: yoyo, Sentiment Score: 0.4
# Word: yvw, Sentiment Score: 1.6
# Word: yw, Sentiment Score: 1.8
# Word: ywia, Sentiment Score: 2.5
# Word: zzz, Sentiment Score: -1.2
# Word: [-;, Sentiment Score: 0.5
# Word: [:, Sentiment Score: 1.3
# Word: [;, Sentiment Score: 1.0
# Word: [=, Sentiment Score: 1.7
# Word: \-:, Sentiment Score: -1.0
# Word: \:, Sentiment Score: -1.0
# Word: \:<, Sentiment Score: -1.7
# Word: \=, Sentiment Score: -1.1
# Word: \^:, Sentiment Score: -1.3
# Word: \o/, Sentiment Score: 2.2
# Word: \o:, Sentiment Score: -1.2
# Word: ]-:, Sentiment Score: -2.1
# Word: ]:, Sentiment Score: -1.6
# Word: ]:<, Sentiment Score: -2.5
# Word: ^<_<, Sentiment Score: 1.4
# Word: ^urs, Sentiment Score: -2.8
# Word: abandon, Sentiment Score: -1.9
# Word: abandoned, Sentiment Score: -2.0
# Word: abandoner, Sentiment Score: -1.9
# Word: abandoners, Sentiment Score: -1.9
# Word: abandoning, Sentiment Score: -1.6
# Word: abandonment, Sentiment Score: -2.4
# Word: abandonments, Sentiment Score: -1.7
# Word: abandons, Sentiment Score: -1.3
# Word: abducted, Sentiment Score: -2.3
# Word: abduction, Sentiment Score: -2.8
# Word: abductions, Sentiment Score: -2.0
# Word: abhor, Sentiment Score: -2.0
# Word: abhorred, Sentiment Score: -2.4
# Word: abhorrent, Sentiment Score: -3.1
# Word: abhors, Sentiment Score: -2.9
# Word: abilities, Sentiment Score: 1.0
# Word: ability, Sentiment Score: 1.3
# Word: aboard, Sentiment Score: 0.1
# Word: absentee, Sentiment Score: -1.1
# Word: absentees, Sentiment Score: -0.8
# Word: absolve, Sentiment Score: 1.2
# Word: absolved, Sentiment Score: 1.5
# Word: absolves, Sentiment Score: 1.3
# Word: absolving, Sentiment Score: 1.6
# Word: abuse, Sentiment Score: -3.2
# Word: abused, Sentiment Score: -2.3
# Word: abuser, Sentiment Score: -2.6
# Word: abusers, Sentiment Score: -2.6
# Word: abuses, Sentiment Score: -2.6
# Word: abusing, Sentiment Score: -2.0
# Word: abusive, Sentiment Score: -3.2
# Word: abusively, Sentiment Score: -2.8
# Word: abusiveness, Sentiment Score: -2.5
# Word: abusivenesses, Sentiment Score: -3.0
# Word: accept, Sentiment Score: 1.6
# Word: acceptabilities, Sentiment Score: 1.6
# Word: acceptability, Sentiment Score: 1.1
# Word: acceptable, Sentiment Score: 1.3
# Word: acceptableness, Sentiment Score: 1.3
# Word: acceptably, Sentiment Score: 1.5
# Word: acceptance, Sentiment Score: 2.0
# Word: acceptances, Sentiment Score: 1.7
# Word: acceptant, Sentiment Score: 1.6
# Word: acceptation, Sentiment Score: 1.3
# Word: acceptations, Sentiment Score: 0.9
# Word: accepted, Sentiment Score: 1.1
# Word: accepting, Sentiment Score: 1.6
# Word: accepts, Sentiment Score: 1.3
# Word: accident, Sentiment Score: -2.1
# Word: accidental, Sentiment Score: -0.3
# Word: accidentally, Sentiment Score: -1.4
# Word: accidents, Sentiment Score: -1.3
# Word: accomplish, Sentiment Score: 1.8
# Word: accomplished, Sentiment Score: 1.9
# Word: accomplishes, Sentiment Score: 1.7
# Word: accusation, Sentiment Score: -1.0
# Word: accusations, Sentiment Score: -1.3
# Word: accuse, Sentiment Score: -0.8
# Word: accused, Sentiment Score: -1.2
# Word: accuses, Sentiment Score: -1.4
# Word: accusing, Sentiment Score: -0.7
# Word: ache, Sentiment Score: -1.6
# Word: ached, Sentiment Score: -1.6
# Word: aches, Sentiment Score: -1.0
# Word: achievable, Sentiment Score: 1.3
# Word: aching, Sentiment Score: -2.2
# Word: acquit, Sentiment Score: 0.8
# Word: acquits, Sentiment Score: 0.1
# Word: acquitted, Sentiment Score: 1.0
# Word: acquitting, Sentiment Score: 1.3
# Word: acrimonious, Sentiment Score: -1.7
# Word: active, Sentiment Score: 1.7
# Word: actively, Sentiment Score: 1.3
# Word: activeness, Sentiment Score: 0.6
# Word: activenesses, Sentiment Score: 0.8
# Word: actives, Sentiment Score: 1.1
# Word: adequate, Sentiment Score: 0.9
# Word: admirability, Sentiment Score: 2.4
# Word: admirable, Sentiment Score: 2.6
# Word: admirableness, Sentiment Score: 2.2
# Word: admirably, Sentiment Score: 2.5
# Word: admiral, Sentiment Score: 1.3
# Word: admirals, Sentiment Score: 1.5
# Word: admiralties, Sentiment Score: 1.6
# Word: admiralty, Sentiment Score: 1.2
# Word: admiration, Sentiment Score: 2.5
# Word: admirations, Sentiment Score: 1.6
# Word: admire, Sentiment Score: 2.1
# Word: admired, Sentiment Score: 2.3
# Word: admirer, Sentiment Score: 1.8
# Word: admirers, Sentiment Score: 1.7
# Word: admires, Sentiment Score: 1.5
# Word: admiring, Sentiment Score: 1.6
# Word: admiringly, Sentiment Score: 2.3
# Word: admit, Sentiment Score: 0.8
# Word: admits, Sentiment Score: 1.2
# Word: admitted, Sentiment Score: 0.4
# Word: admonished, Sentiment Score: -1.9
# Word: adopt, Sentiment Score: 0.7
# Word: adopts, Sentiment Score: 0.7
# Word: adorability, Sentiment Score: 2.2
# Word: adorable, Sentiment Score: 2.2
# Word: adorableness, Sentiment Score: 2.5
# Word: adorably, Sentiment Score: 2.1
# Word: adoration, Sentiment Score: 2.9
# Word: adorations, Sentiment Score: 2.2
# Word: adore, Sentiment Score: 2.6
# Word: adored, Sentiment Score: 1.8
# Word: adorer, Sentiment Score: 1.7
# Word: adorers, Sentiment Score: 2.1
# Word: adores, Sentiment Score: 1.6
# Word: adoring, Sentiment Score: 2.6
# Word: adoringly, Sentiment Score: 2.4
# Word: adorn, Sentiment Score: 0.9
# Word: adorned, Sentiment Score: 0.8
# Word: adorner, Sentiment Score: 1.3
# Word: adorners, Sentiment Score: 0.9
# Word: adorning, Sentiment Score: 1.0
# Word: adornment, Sentiment Score: 1.3
# Word: adornments, Sentiment Score: 0.8
# Word: adorns, Sentiment Score: 0.5
# Word: advanced, Sentiment Score: 1.0
# Word: advantage, Sentiment Score: 1.0
# Word: advantaged, Sentiment Score: 1.4
# Word: advantageous, Sentiment Score: 1.5
# Word: advantageously, Sentiment Score: 1.9
# Word: advantageousness, Sentiment Score: 1.6
# Word: advantages, Sentiment Score: 1.5
# Word: advantaging, Sentiment Score: 1.6
# Word: adventure, Sentiment Score: 1.3
# Word: adventured, Sentiment Score: 1.3
# Word: adventurer, Sentiment Score: 1.2
# Word: adventurers, Sentiment Score: 0.9
# Word: adventures, Sentiment Score: 1.4
# Word: adventuresome, Sentiment Score: 1.7
# Word: adventuresomeness, Sentiment Score: 1.3
# Word: adventuress, Sentiment Score: 0.8
# Word: adventuresses, Sentiment Score: 1.4
# Word: adventuring, Sentiment Score: 2.3
# Word: adventurism, Sentiment Score: 1.5
# Word: adventurist, Sentiment Score: 1.4
# Word: adventuristic, Sentiment Score: 1.7
# Word: adventurists, Sentiment Score: 1.2
# Word: adventurous, Sentiment Score: 1.4
# Word: adventurously, Sentiment Score: 1.3
# Word: adventurousness, Sentiment Score: 1.8
# Word: adversarial, Sentiment Score: -1.5
# Word: adversaries, Sentiment Score: -1.0
# Word: adversary, Sentiment Score: -0.8
# Word: adversative, Sentiment Score: -1.2
# Word: adversatively, Sentiment Score: -0.1
# Word: adversatives, Sentiment Score: -1.0
# Word: adverse, Sentiment Score: -1.5
# Word: adversely, Sentiment Score: -0.8
# Word: adverseness, Sentiment Score: -0.6
# Word: adversities, Sentiment Score: -1.5
# Word: adversity, Sentiment Score: -1.8
# Word: affected, Sentiment Score: -0.6
# Word: affection, Sentiment Score: 2.4
# Word: affectional, Sentiment Score: 1.9
# Word: affectionally, Sentiment Score: 1.5
# Word: affectionate, Sentiment Score: 1.9
# Word: affectionately, Sentiment Score: 2.2
# Word: affectioned, Sentiment Score: 1.8
# Word: affectionless, Sentiment Score: -2.0
# Word: affections, Sentiment Score: 1.5
# Word: afflicted, Sentiment Score: -1.5
# Word: affronted, Sentiment Score: 0.2
# Word: aggravate, Sentiment Score: -2.5
# Word: aggravated, Sentiment Score: -1.9
# Word: aggravates, Sentiment Score: -1.9
# Word: aggravating, Sentiment Score: -1.2
# Word: aggress, Sentiment Score: -1.3
# Word: aggressed, Sentiment Score: -1.4
# Word: aggresses, Sentiment Score: -0.5
# Word: aggressing, Sentiment Score: -0.6
# Word: aggression, Sentiment Score: -1.2
# Word: aggressions, Sentiment Score: -1.3
# Word: aggressive, Sentiment Score: -0.6
# Word: aggressively, Sentiment Score: -1.3
# Word: aggressiveness, Sentiment Score: -1.8
# Word: aggressivities, Sentiment Score: -1.4
# Word: aggressivity, Sentiment Score: -0.6
# Word: aggressor, Sentiment Score: -0.8
# Word: aggressors, Sentiment Score: -0.9
# Word: aghast, Sentiment Score: -1.9
# Word: agitate, Sentiment Score: -1.7
# Word: agitated, Sentiment Score: -2.0
# Word: agitatedly, Sentiment Score: -1.6
# Word: agitates, Sentiment Score: -1.4
# Word: agitating, Sentiment Score: -1.8
# Word: agitation, Sentiment Score: -1.0
# Word: agitational, Sentiment Score: -1.2
# Word: agitations, Sentiment Score: -1.3
# Word: agitative, Sentiment Score: -1.3
# Word: agitato, Sentiment Score: -0.1
# Word: agitator, Sentiment Score: -1.4
# Word: agitators, Sentiment Score: -2.1
# Word: agog, Sentiment Score: 1.9
# Word: agonise, Sentiment Score: -2.1
# Word: agonised, Sentiment Score: -2.3
# Word: agonises, Sentiment Score: -2.4
# Word: agonising, Sentiment Score: -1.5
# Word: agonize, Sentiment Score: -2.3
# Word: agonized, Sentiment Score: -2.2
# Word: agonizes, Sentiment Score: -2.3
# Word: agonizing, Sentiment Score: -2.7
# Word: agonizingly, Sentiment Score: -2.3
# Word: agony, Sentiment Score: -1.8
# Word: agree, Sentiment Score: 1.5
# Word: agreeability, Sentiment Score: 1.9
# Word: agreeable, Sentiment Score: 1.8
# Word: agreeableness, Sentiment Score: 1.8
# Word: agreeablenesses, Sentiment Score: 1.3
# Word: agreeably, Sentiment Score: 1.6
# Word: agreed, Sentiment Score: 1.1
# Word: agreeing, Sentiment Score: 1.4
# Word: agreement, Sentiment Score: 2.2
# Word: agreements, Sentiment Score: 1.1
# Word: agrees, Sentiment Score: 0.8
# Word: alarm, Sentiment Score: -1.4
# Word: alarmed, Sentiment Score: -1.4
# Word: alarming, Sentiment Score: -0.5
# Word: alarmingly, Sentiment Score: -2.6
# Word: alarmism, Sentiment Score: -0.3
# Word: alarmists, Sentiment Score: -1.1
# Word: alarms, Sentiment Score: -1.1
# Word: alas, Sentiment Score: -1.1
# Word: alert, Sentiment Score: 1.2
# Word: alienation, Sentiment Score: -1.1
# Word: alive, Sentiment Score: 1.6
# Word: allergic, Sentiment Score: -1.2
# Word: allow, Sentiment Score: 0.9
# Word: alone, Sentiment Score: -1.0
# Word: alright, Sentiment Score: 1.0
# Word: amaze, Sentiment Score: 2.5
# Word: amazed, Sentiment Score: 2.2
# Word: amazedly, Sentiment Score: 2.1
# Word: amazement, Sentiment Score: 2.5
# Word: amazements, Sentiment Score: 2.2
# Word: amazes, Sentiment Score: 2.2
# Word: amazing, Sentiment Score: 2.8
# Word: amazon, Sentiment Score: 0.7
# Word: amazonite, Sentiment Score: 0.2
# Word: amazons, Sentiment Score: -0.1
# Word: amazonstone, Sentiment Score: 1.0
# Word: amazonstones, Sentiment Score: 0.2
# Word: ambitious, Sentiment Score: 2.1
# Word: ambivalent, Sentiment Score: 0.5
# Word: amor, Sentiment Score: 3.0
# Word: amoral, Sentiment Score: -1.6
# Word: amoralism, Sentiment Score: -0.7
# Word: amoralisms, Sentiment Score: -0.7
# Word: amoralities, Sentiment Score: -1.2
# Word: amorality, Sentiment Score: -1.5
# Word: amorally, Sentiment Score: -1.0
# Word: amoretti, Sentiment Score: 0.2
# Word: amoretto, Sentiment Score: 0.6
# Word: amorettos, Sentiment Score: 0.3
# Word: amorino, Sentiment Score: 1.2
# Word: amorist, Sentiment Score: 1.6
# Word: amoristic, Sentiment Score: 1.0
# Word: amorists, Sentiment Score: 0.1
# Word: amoroso, Sentiment Score: 2.3
# Word: amorous, Sentiment Score: 1.8
# Word: amorously, Sentiment Score: 2.3
# Word: amorousness, Sentiment Score: 2.0
# Word: amorphous, Sentiment Score: -0.2
# Word: amorphously, Sentiment Score: 0.1
# Word: amorphousness, Sentiment Score: 0.3
# Word: amort, Sentiment Score: -2.1
# Word: amortise, Sentiment Score: 0.5
# Word: amortised, Sentiment Score: -0.2
# Word: amortises, Sentiment Score: 0.1
# Word: amortizable, Sentiment Score: 0.5
# Word: amortization, Sentiment Score: 0.6
# Word: amortizations, Sentiment Score: 0.2
# Word: amortize, Sentiment Score: -0.1
# Word: amortized, Sentiment Score: 0.8
# Word: amortizes, Sentiment Score: 0.6
# Word: amortizing, Sentiment Score: 0.8
# Word: amusable, Sentiment Score: 0.7
# Word: amuse, Sentiment Score: 1.7
# Word: amused, Sentiment Score: 1.8
# Word: amusedly, Sentiment Score: 2.2
# Word: amusement, Sentiment Score: 1.5
# Word: amusements, Sentiment Score: 1.5
# Word: amuser, Sentiment Score: 1.1
# Word: amusers, Sentiment Score: 1.3
# Word: amuses, Sentiment Score: 1.7
# Word: amusia, Sentiment Score: 0.3
# Word: amusias, Sentiment Score: -0.4
# Word: amusing, Sentiment Score: 1.6
# Word: amusingly, Sentiment Score: 0.8
# Word: amusingness, Sentiment Score: 1.8
# Word: amusive, Sentiment Score: 1.7
# Word: anger, Sentiment Score: -2.7
# Word: angered, Sentiment Score: -2.3
# Word: angering, Sentiment Score: -2.2
# Word: angerly, Sentiment Score: -1.9
# Word: angers, Sentiment Score: -2.3
# Word: angrier, Sentiment Score: -2.3
# Word: angriest, Sentiment Score: -3.1
# Word: angrily, Sentiment Score: -1.8
# Word: angriness, Sentiment Score: -1.7
# Word: angry, Sentiment Score: -2.3
# Word: anguish, Sentiment Score: -2.9
# Word: anguished, Sentiment Score: -1.8
# Word: anguishes, Sentiment Score: -2.1
# Word: anguishing, Sentiment Score: -2.7
# Word: animosity, Sentiment Score: -1.9
# Word: annoy, Sentiment Score: -1.9
# Word: annoyance, Sentiment Score: -1.3
# Word: annoyances, Sentiment Score: -1.8
# Word: annoyed, Sentiment Score: -1.6
# Word: annoyer, Sentiment Score: -2.2
# Word: annoyers, Sentiment Score: -1.5
# Word: annoying, Sentiment Score: -1.7
# Word: annoys, Sentiment Score: -1.8
# Word: antagonism, Sentiment Score: -1.9
# Word: antagonisms, Sentiment Score: -1.2
# Word: antagonist, Sentiment Score: -1.9
# Word: antagonistic, Sentiment Score: -1.7
# Word: antagonistically, Sentiment Score: -2.2
# Word: antagonists, Sentiment Score: -1.7
# Word: antagonize, Sentiment Score: -2.0
# Word: antagonized, Sentiment Score: -1.4
# Word: antagonizes, Sentiment Score: -0.5
# Word: antagonizing, Sentiment Score: -2.7
# Word: anti, Sentiment Score: -1.3
# Word: anticipation, Sentiment Score: 0.4
# Word: anxieties, Sentiment Score: -0.6
# Word: anxiety, Sentiment Score: -0.7
# Word: anxious, Sentiment Score: -1.0
# Word: anxiously, Sentiment Score: -0.9
# Word: anxiousness, Sentiment Score: -1.0
# Word: aok, Sentiment Score: 2.0
# Word: apathetic, Sentiment Score: -1.2
# Word: apathetically, Sentiment Score: -0.4
# Word: apathies, Sentiment Score: -0.6
# Word: apathy, Sentiment Score: -1.2
# Word: apeshit, Sentiment Score: -0.9
# Word: apocalyptic, Sentiment Score: -3.4
# Word: apologise, Sentiment Score: 1.6
# Word: apologised, Sentiment Score: 0.4
# Word: apologises, Sentiment Score: 0.8
# Word: apologising, Sentiment Score: 0.2
# Word: apologize, Sentiment Score: 0.4
# Word: apologized, Sentiment Score: 1.3
# Word: apologizes, Sentiment Score: 1.5
# Word: apologizing, Sentiment Score: -0.3
# Word: apology, Sentiment Score: 0.2
# Word: appall, Sentiment Score: -2.4
# Word: appalled, Sentiment Score: -2.0
# Word: appalling, Sentiment Score: -1.5
# Word: appallingly, Sentiment Score: -2.0
# Word: appalls, Sentiment Score: -1.9
# Word: appease, Sentiment Score: 1.1
# Word: appeased, Sentiment Score: 0.9
# Word: appeases, Sentiment Score: 0.9
# Word: appeasing, Sentiment Score: 1.0
# Word: applaud, Sentiment Score: 2.0
# Word: applauded, Sentiment Score: 1.5
# Word: applauding, Sentiment Score: 2.1
# Word: applauds, Sentiment Score: 1.4
# Word: applause, Sentiment Score: 1.8
# Word: appreciate, Sentiment Score: 1.7
# Word: appreciated, Sentiment Score: 2.3
# Word: appreciates, Sentiment Score: 2.3
# Word: appreciating, Sentiment Score: 1.9
# Word: appreciation, Sentiment Score: 2.3
# Word: appreciations, Sentiment Score: 1.7
# Word: appreciative, Sentiment Score: 2.6
# Word: appreciatively, Sentiment Score: 1.8
# Word: appreciativeness, Sentiment Score: 1.6
# Word: appreciator, Sentiment Score: 2.6
# Word: appreciators, Sentiment Score: 1.5
# Word: appreciatory, Sentiment Score: 1.7
# Word: apprehensible, Sentiment Score: 1.1
# Word: apprehensibly, Sentiment Score: -0.2
# Word: apprehension, Sentiment Score: -2.1
# Word: apprehensions, Sentiment Score: -0.9
# Word: apprehensively, Sentiment Score: -0.3
# Word: apprehensiveness, Sentiment Score: -0.7
# Word: approval, Sentiment Score: 2.1
# Word: approved, Sentiment Score: 1.8
# Word: approves, Sentiment Score: 1.7
# Word: ardent, Sentiment Score: 2.1
# Word: arguable, Sentiment Score: -1.0
# Word: arguably, Sentiment Score: -1.0
# Word: argue, Sentiment Score: -1.4
# Word: argued, Sentiment Score: -1.5
# Word: arguer, Sentiment Score: -1.6
# Word: arguers, Sentiment Score: -1.4
# Word: argues, Sentiment Score: -1.6
# Word: arguing, Sentiment Score: -2.0
# Word: argument, Sentiment Score: -1.5
# Word: argumentative, Sentiment Score: -1.5
# Word: argumentatively, Sentiment Score: -1.8
# Word: argumentive, Sentiment Score: -1.5
# Word: arguments, Sentiment Score: -1.7
# Word: arrest, Sentiment Score: -1.4
# Word: arrested, Sentiment Score: -2.1
# Word: arrests, Sentiment Score: -1.9
# Word: arrogance, Sentiment Score: -2.4
# Word: arrogances, Sentiment Score: -1.9
# Word: arrogant, Sentiment Score: -2.2
# Word: arrogantly, Sentiment Score: -1.8
# Word: ashamed, Sentiment Score: -2.1
# Word: ashamedly, Sentiment Score: -1.7
# Word: ass, Sentiment Score: -2.5
# Word: assassination, Sentiment Score: -2.9
# Word: assassinations, Sentiment Score: -2.7
# Word: assault, Sentiment Score: -2.8
# Word: assaulted, Sentiment Score: -2.4
# Word: assaulting, Sentiment Score: -2.3
# Word: assaultive, Sentiment Score: -2.8
# Word: assaults, Sentiment Score: -2.5
# Word: asset, Sentiment Score: 1.5
# Word: assets, Sentiment Score: 0.7
# Word: assfucking, Sentiment Score: -2.5
# Word: assholes, Sentiment Score: -2.8
# Word: assurance, Sentiment Score: 1.4
# Word: assurances, Sentiment Score: 1.4
# Word: assure, Sentiment Score: 1.4
# Word: assured, Sentiment Score: 1.5
# Word: assuredly, Sentiment Score: 1.6
# Word: assuredness, Sentiment Score: 1.4
# Word: assurer, Sentiment Score: 0.9
# Word: assurers, Sentiment Score: 1.1
# Word: assures, Sentiment Score: 1.3
# Word: assurgent, Sentiment Score: 1.3
# Word: assuring, Sentiment Score: 1.6
# Word: assuror, Sentiment Score: 0.5
# Word: assurors, Sentiment Score: 0.7
# Word: astonished, Sentiment Score: 1.6
# Word: astound, Sentiment Score: 1.7
# Word: astounded, Sentiment Score: 1.8
# Word: astounding, Sentiment Score: 1.8
# Word: astoundingly, Sentiment Score: 2.1
# Word: astounds, Sentiment Score: 2.1
# Word: attachment, Sentiment Score: 1.2
# Word: attachments, Sentiment Score: 1.1
# Word: attack, Sentiment Score: -2.1
# Word: attacked, Sentiment Score: -2.0
# Word: attacker, Sentiment Score: -2.7
# Word: attackers, Sentiment Score: -2.7
# Word: attacking, Sentiment Score: -2.0
# Word: attacks, Sentiment Score: -1.9
# Word: attract, Sentiment Score: 1.5
# Word: attractancy, Sentiment Score: 0.9
# Word: attractant, Sentiment Score: 1.3
# Word: attractants, Sentiment Score: 1.4
# Word: attracted, Sentiment Score: 1.8
# Word: attracting, Sentiment Score: 2.1
# Word: attraction, Sentiment Score: 2.0
# Word: attractions, Sentiment Score: 1.8
# Word: attractive, Sentiment Score: 1.9
# Word: attractively, Sentiment Score: 2.2
# Word: attractiveness, Sentiment Score: 1.8
# Word: attractivenesses, Sentiment Score: 2.1
# Word: attractor, Sentiment Score: 1.2
# Word: attractors, Sentiment Score: 1.2
# Word: attracts, Sentiment Score: 1.7
# Word: audacious, Sentiment Score: 0.9
# Word: authority, Sentiment Score: 0.3
# Word: aversion, Sentiment Score: -1.9
# Word: aversions, Sentiment Score: -1.1
# Word: aversive, Sentiment Score: -1.6
# Word: aversively, Sentiment Score: -0.8
# Word: avert, Sentiment Score: -0.7
# Word: averted, Sentiment Score: -0.3
# Word: averts, Sentiment Score: -0.4
# Word: avid, Sentiment Score: 1.2
# Word: avoid, Sentiment Score: -1.2
# Word: avoidance, Sentiment Score: -1.7
# Word: avoidances, Sentiment Score: -1.1
# Word: avoided, Sentiment Score: -1.4
# Word: avoider, Sentiment Score: -1.8
# Word: avoiders, Sentiment Score: -1.4
# Word: avoiding, Sentiment Score: -1.4
# Word: avoids, Sentiment Score: -0.7
# Word: await, Sentiment Score: 0.4
# Word: awaited, Sentiment Score: -0.1
# Word: awaits, Sentiment Score: 0.3
# Word: award, Sentiment Score: 2.5
# Word: awardable, Sentiment Score: 2.4
# Word: awarded, Sentiment Score: 1.7
# Word: awardee, Sentiment Score: 1.8
# Word: awardees, Sentiment Score: 1.2
# Word: awarder, Sentiment Score: 0.9
# Word: awarders, Sentiment Score: 1.3
# Word: awarding, Sentiment Score: 1.9
# Word: awards, Sentiment Score: 2.0
# Word: awesome, Sentiment Score: 3.1
# Word: awful, Sentiment Score: -2.0
# Word: awkward, Sentiment Score: -0.6
# Word: awkwardly, Sentiment Score: -1.3
# Word: awkwardness, Sentiment Score: -0.7
# Word: axe, Sentiment Score: -0.4
# Word: axed, Sentiment Score: -1.3
# Word: backed, Sentiment Score: 0.1
# Word: backing, Sentiment Score: 0.1
# Word: backs, Sentiment Score: -0.2
# Word: bad, Sentiment Score: -2.5
# Word: badass, Sentiment Score: 1.4
# Word: badly, Sentiment Score: -2.1
# Word: bailout, Sentiment Score: -0.4
# Word: bamboozle, Sentiment Score: -1.5
# Word: bamboozled, Sentiment Score: -1.5
# Word: bamboozles, Sentiment Score: -1.5
# Word: ban, Sentiment Score: -2.6
# Word: banish, Sentiment Score: -1.9
# Word: bankrupt, Sentiment Score: -2.6
# Word: bankster, Sentiment Score: -2.1
# Word: banned, Sentiment Score: -2.0
# Word: bargain, Sentiment Score: 0.8
# Word: barrier, Sentiment Score: -0.5
# Word: bashful, Sentiment Score: -0.1
# Word: bashfully, Sentiment Score: 0.2
# Word: bashfulness, Sentiment Score: -0.8
# Word: bastard, Sentiment Score: -2.5
# Word: bastardies, Sentiment Score: -1.8
# Word: bastardise, Sentiment Score: -2.1
# Word: bastardised, Sentiment Score: -2.3
# Word: bastardises, Sentiment Score: -2.3
# Word: bastardising, Sentiment Score: -2.6
# Word: bastardization, Sentiment Score: -2.4
# Word: bastardizations, Sentiment Score: -2.1
# Word: bastardize, Sentiment Score: -2.4
# Word: bastardized, Sentiment Score: -2.0
# Word: bastardizes, Sentiment Score: -1.8
# Word: bastardizing, Sentiment Score: -2.3
# Word: bastardly, Sentiment Score: -2.7
# Word: bastards, Sentiment Score: -3.0
# Word: bastardy, Sentiment Score: -2.7
# Word: battle, Sentiment Score: -1.6
# Word: battled, Sentiment Score: -1.2
# Word: battlefield, Sentiment Score: -1.6
# Word: battlefields, Sentiment Score: -0.9
# Word: battlefront, Sentiment Score: -1.2
# Word: battlefronts, Sentiment Score: -0.8
# Word: battleground, Sentiment Score: -1.7
# Word: battlegrounds, Sentiment Score: -0.6
# Word: battlement, Sentiment Score: -0.4
# Word: battlements, Sentiment Score: -0.4
# Word: battler, Sentiment Score: -0.8
# Word: battlers, Sentiment Score: -0.2
# Word: battles, Sentiment Score: -1.6
# Word: battleship, Sentiment Score: -0.1
# Word: battleships, Sentiment Score: -0.5
# Word: battlewagon, Sentiment Score: -0.3
# Word: battlewagons, Sentiment Score: -0.5
# Word: battling, Sentiment Score: -1.1
# Word: beaten, Sentiment Score: -1.8
# Word: beatific, Sentiment Score: 1.8
# Word: beating, Sentiment Score: -2.0
# Word: beaut, Sentiment Score: 1.6
# Word: beauteous, Sentiment Score: 2.5
# Word: beauteously, Sentiment Score: 2.6
# Word: beauteousness, Sentiment Score: 2.7
# Word: beautician, Sentiment Score: 1.2
# Word: beauticians, Sentiment Score: 0.4
# Word: beauties, Sentiment Score: 2.4
# Word: beautification, Sentiment Score: 1.9
# Word: beautifications, Sentiment Score: 2.4
# Word: beautified, Sentiment Score: 2.1
# Word: beautifier, Sentiment Score: 1.7
# Word: beautifiers, Sentiment Score: 1.7
# Word: beautifies, Sentiment Score: 1.8
# Word: beautiful, Sentiment Score: 2.9
# Word: beautifuler, Sentiment Score: 2.1
# Word: beautifulest, Sentiment Score: 2.6
# Word: beautifully, Sentiment Score: 2.7
# Word: beautifulness, Sentiment Score: 2.6
# Word: beautify, Sentiment Score: 2.3
# Word: beautifying, Sentiment Score: 2.3
# Word: beauts, Sentiment Score: 1.7
# Word: beauty, Sentiment Score: 2.8
# Word: belittle, Sentiment Score: -1.9
# Word: belittled, Sentiment Score: -2.0
# Word: beloved, Sentiment Score: 2.3
# Word: benefic, Sentiment Score: 1.4
# Word: benefice, Sentiment Score: 0.4
# Word: beneficed, Sentiment Score: 1.1
# Word: beneficence, Sentiment Score: 2.8
# Word: beneficences, Sentiment Score: 1.5
# Word: beneficent, Sentiment Score: 2.3
# Word: beneficently, Sentiment Score: 2.2
# Word: benefices, Sentiment Score: 1.1
# Word: beneficial, Sentiment Score: 1.9
# Word: beneficially, Sentiment Score: 2.4
# Word: beneficialness, Sentiment Score: 1.7
# Word: beneficiaries, Sentiment Score: 1.8
# Word: beneficiary, Sentiment Score: 2.1
# Word: beneficiate, Sentiment Score: 1.0
# Word: beneficiation, Sentiment Score: 0.4
# Word: benefit, Sentiment Score: 2.0
# Word: benefits, Sentiment Score: 1.6
# Word: benefitted, Sentiment Score: 1.7
# Word: benefitting, Sentiment Score: 1.9
# Word: benevolence, Sentiment Score: 1.7
# Word: benevolences, Sentiment Score: 1.9
# Word: benevolent, Sentiment Score: 2.7
# Word: benevolently, Sentiment Score: 1.4
# Word: benevolentness, Sentiment Score: 1.2
# Word: benign, Sentiment Score: 1.3
# Word: benignancy, Sentiment Score: 0.6
# Word: benignant, Sentiment Score: 2.2
# Word: benignantly, Sentiment Score: 1.1
# Word: benignities, Sentiment Score: 0.9
# Word: benignity, Sentiment Score: 1.3
# Word: benignly, Sentiment Score: 0.2
# Word: bereave, Sentiment Score: -2.1
# Word: bereaved, Sentiment Score: -2.1
# Word: bereaves, Sentiment Score: -1.9
# Word: bereaving, Sentiment Score: -1.3
# Word: best, Sentiment Score: 3.2
# Word: betray, Sentiment Score: -3.2
# Word: betrayal, Sentiment Score: -2.8
# Word: betrayed, Sentiment Score: -3.0
# Word: betraying, Sentiment Score: -2.5
# Word: betrays, Sentiment Score: -2.5
# Word: better, Sentiment Score: 1.9
# Word: bias, Sentiment Score: -0.4
# Word: biased, Sentiment Score: -1.1
# Word: bitch, Sentiment Score: -2.8
# Word: bitched, Sentiment Score: -2.6
# Word: bitcheries, Sentiment Score: -2.3
# Word: bitchery, Sentiment Score: -2.7
# Word: bitches, Sentiment Score: -2.9
# Word: bitchier, Sentiment Score: -2.0
# Word: bitchiest, Sentiment Score: -3.0
# Word: bitchily, Sentiment Score: -2.6
# Word: bitchiness, Sentiment Score: -2.6
# Word: bitching, Sentiment Score: -1.1
# Word: bitchy, Sentiment Score: -2.3
# Word: bitter, Sentiment Score: -1.8
# Word: bitterbrush, Sentiment Score: -0.2
# Word: bitterbrushes, Sentiment Score: -0.6
# Word: bittered, Sentiment Score: -1.8
# Word: bitterer, Sentiment Score: -1.9
# Word: bitterest, Sentiment Score: -2.3
# Word: bittering, Sentiment Score: -1.2
# Word: bitterish, Sentiment Score: -1.6
# Word: bitterly, Sentiment Score: -2.0
# Word: bittern, Sentiment Score: -0.2
# Word: bitterness, Sentiment Score: -1.7
# Word: bitterns, Sentiment Score: -0.4
# Word: bitterroots, Sentiment Score: -0.2
# Word: bitters, Sentiment Score: -0.4
# Word: bittersweet, Sentiment Score: -0.3
# Word: bittersweetness, Sentiment Score: -0.6
# Word: bittersweets, Sentiment Score: -0.2
# Word: bitterweeds, Sentiment Score: -0.5
# Word: bizarre, Sentiment Score: -1.3
# Word: blah, Sentiment Score: -0.4
# Word: blam, Sentiment Score: -0.2
# Word: blamable, Sentiment Score: -1.8
# Word: blamably, Sentiment Score: -1.8
# Word: blame, Sentiment Score: -1.4
# Word: blamed, Sentiment Score: -2.1
# Word: blameful, Sentiment Score: -1.7
# Word: blamefully, Sentiment Score: -1.6
# Word: blameless, Sentiment Score: 0.7
# Word: blamelessly, Sentiment Score: 0.9
# Word: blamelessness, Sentiment Score: 0.6
# Word: blamer, Sentiment Score: -2.1
# Word: blamers, Sentiment Score: -2.0
# Word: blames, Sentiment Score: -1.7
# Word: blameworthiness, Sentiment Score: -1.6
# Word: blameworthy, Sentiment Score: -2.3
# Word: blaming, Sentiment Score: -2.2
# Word: bless, Sentiment Score: 1.8
# Word: blessed, Sentiment Score: 2.9
# Word: blesseder, Sentiment Score: 2.0
# Word: blessedest, Sentiment Score: 2.8
# Word: blessedly, Sentiment Score: 1.7
# Word: blessedness, Sentiment Score: 1.6
# Word: blesser, Sentiment Score: 2.6
# Word: blessers, Sentiment Score: 1.9
# Word: blesses, Sentiment Score: 2.6
# Word: blessing, Sentiment Score: 2.2
# Word: blessings, Sentiment Score: 2.5
# Word: blind, Sentiment Score: -1.7
# Word: bliss, Sentiment Score: 2.7
# Word: blissful, Sentiment Score: 2.9
# Word: blithe, Sentiment Score: 1.2
# Word: block, Sentiment Score: -1.9
# Word: blockbuster, Sentiment Score: 2.9
# Word: blocked, Sentiment Score: -1.1
# Word: blocking, Sentiment Score: -1.6
# Word: blocks, Sentiment Score: -0.9
# Word: bloody, Sentiment Score: -1.9
# Word: blurry, Sentiment Score: -0.4
# Word: bold, Sentiment Score: 1.6
# Word: bolder, Sentiment Score: 1.2
# Word: boldest, Sentiment Score: 1.6
# Word: boldface, Sentiment Score: 0.3
# Word: boldfaced, Sentiment Score: -0.1
# Word: boldfaces, Sentiment Score: 0.1
# Word: boldfacing, Sentiment Score: 0.1
# Word: boldly, Sentiment Score: 1.5
# Word: boldness, Sentiment Score: 1.5
# Word: boldnesses, Sentiment Score: 0.9
# Word: bolds, Sentiment Score: 1.3
# Word: bomb, Sentiment Score: -2.2
# Word: bonus, Sentiment Score: 2.5
# Word: bonuses, Sentiment Score: 2.6
# Word: boost, Sentiment Score: 1.7
# Word: boosted, Sentiment Score: 1.5
# Word: boosting, Sentiment Score: 1.4
# Word: boosts, Sentiment Score: 1.3
# Word: bore, Sentiment Score: -1.0
# Word: boreal, Sentiment Score: -0.3
# Word: borecole, Sentiment Score: -0.2
# Word: borecoles, Sentiment Score: -0.3
# Word: bored, Sentiment Score: -1.1
# Word: boredom, Sentiment Score: -1.3
# Word: boredoms, Sentiment Score: -1.1
# Word: boreen, Sentiment Score: 0.1
# Word: boreens, Sentiment Score: 0.2
# Word: boreholes, Sentiment Score: -0.2
# Word: borer, Sentiment Score: -0.4
# Word: borers, Sentiment Score: -1.2
# Word: bores, Sentiment Score: -1.3
# Word: borescopes, Sentiment Score: -0.1
# Word: boresome, Sentiment Score: -1.3
# Word: boring, Sentiment Score: -1.3
# Word: bother, Sentiment Score: -1.4
# Word: botheration, Sentiment Score: -1.7
# Word: botherations, Sentiment Score: -1.3
# Word: bothered, Sentiment Score: -1.3
# Word: bothering, Sentiment Score: -1.6
# Word: bothers, Sentiment Score: -0.8
# Word: bothersome, Sentiment Score: -1.3
# Word: boycott, Sentiment Score: -1.3
# Word: boycotted, Sentiment Score: -1.7
# Word: boycotting, Sentiment Score: -1.7
# Word: boycotts, Sentiment Score: -1.4
# Word: brainwashing, Sentiment Score: -1.5
# Word: brave, Sentiment Score: 2.4
# Word: braved, Sentiment Score: 1.9
# Word: bravely, Sentiment Score: 2.3
# Word: braver, Sentiment Score: 2.4
# Word: braveries, Sentiment Score: 2.0
# Word: bravery, Sentiment Score: 2.2
# Word: braves, Sentiment Score: 1.9
# Word: bravest, Sentiment Score: 2.3
# Word: breathtaking, Sentiment Score: 2.0
# Word: bribe, Sentiment Score: -0.8
# Word: bright, Sentiment Score: 1.9
# Word: brighten, Sentiment Score: 1.9
# Word: brightened, Sentiment Score: 2.1
# Word: brightener, Sentiment Score: 1.0
# Word: brighteners, Sentiment Score: 1.0
# Word: brightening, Sentiment Score: 2.5
# Word: brightens, Sentiment Score: 1.5
# Word: brighter, Sentiment Score: 1.6
# Word: brightest, Sentiment Score: 3.0
# Word: brightly, Sentiment Score: 1.5
# Word: brightness, Sentiment Score: 1.6
# Word: brightnesses, Sentiment Score: 1.4
# Word: brights, Sentiment Score: 0.4
# Word: brightwork, Sentiment Score: 1.1
# Word: brilliance, Sentiment Score: 2.9
# Word: brilliances, Sentiment Score: 2.9
# Word: brilliancies, Sentiment Score: 2.3
# Word: brilliancy, Sentiment Score: 2.6
# Word: brilliant, Sentiment Score: 2.8
# Word: brilliantine, Sentiment Score: 0.8
# Word: brilliantines, Sentiment Score: 2.0
# Word: brilliantly, Sentiment Score: 3.0
# Word: brilliants, Sentiment Score: 1.9
# Word: brisk, Sentiment Score: 0.6
# Word: broke, Sentiment Score: -1.8
# Word: broken, Sentiment Score: -2.1
# Word: brooding, Sentiment Score: 0.1
# Word: brutal, Sentiment Score: -3.1
# Word: brutalise, Sentiment Score: -2.7
# Word: brutalised, Sentiment Score: -2.9
# Word: brutalises, Sentiment Score: -3.2
# Word: brutalising, Sentiment Score: -2.8
# Word: brutalities, Sentiment Score: -2.6
# Word: brutality, Sentiment Score: -3.0
# Word: brutalization, Sentiment Score: -2.1
# Word: brutalizations, Sentiment Score: -2.3
# Word: brutalize, Sentiment Score: -2.9
# Word: brutalized, Sentiment Score: -2.4
# Word: brutalizes, Sentiment Score: -3.2
# Word: brutalizing, Sentiment Score: -3.4
# Word: brutally, Sentiment Score: -3.0
# Word: bullied, Sentiment Score: -3.1
# Word: bullshit, Sentiment Score: -2.8
# Word: bully, Sentiment Score: -2.2
# Word: bullying, Sentiment Score: -2.9
# Word: bummer, Sentiment Score: -1.6
# Word: buoyant, Sentiment Score: 0.9
# Word: burden, Sentiment Score: -1.9
# Word: burdened, Sentiment Score: -1.7
# Word: burdener, Sentiment Score: -1.3
# Word: burdeners, Sentiment Score: -1.7
# Word: burdening, Sentiment Score: -1.4
# Word: burdens, Sentiment Score: -1.5
# Word: burdensome, Sentiment Score: -1.8
# Word: bwahaha, Sentiment Score: 0.4
# Word: bwahahah, Sentiment Score: 2.5
# Word: calm, Sentiment Score: 1.3
# Word: calmative, Sentiment Score: 1.1
# Word: calmatives, Sentiment Score: 0.5
# Word: calmed, Sentiment Score: 1.6
# Word: calmer, Sentiment Score: 1.5
# Word: calmest, Sentiment Score: 1.6
# Word: calming, Sentiment Score: 1.7
# Word: calmly, Sentiment Score: 1.3
# Word: calmness, Sentiment Score: 1.7
# Word: calmnesses, Sentiment Score: 1.6
# Word: calmodulin, Sentiment Score: 0.2
# Word: calms, Sentiment Score: 1.3
# Word: can't stand, Sentiment Score: -2.0
# Word: cancel, Sentiment Score: -1.0
# Word: cancelled, Sentiment Score: -1.0
# Word: cancelling, Sentiment Score: -0.8
# Word: cancels, Sentiment Score: -0.9
# Word: cancer, Sentiment Score: -3.4
# Word: capable, Sentiment Score: 1.6
# Word: captivated, Sentiment Score: 1.6
# Word: care, Sentiment Score: 2.2
# Word: cared, Sentiment Score: 1.8
# Word: carefree, Sentiment Score: 1.7
# Word: careful, Sentiment Score: 0.6
# Word: carefully, Sentiment Score: 0.5
# Word: carefulness, Sentiment Score: 2.0
# Word: careless, Sentiment Score: -1.5
# Word: carelessly, Sentiment Score: -1.0
# Word: carelessness, Sentiment Score: -1.4
# Word: carelessnesses, Sentiment Score: -1.6
# Word: cares, Sentiment Score: 2.0
# Word: caring, Sentiment Score: 2.2
# Word: casual, Sentiment Score: 0.8
# Word: casually, Sentiment Score: 0.7
# Word: casualty, Sentiment Score: -2.4
# Word: catastrophe, Sentiment Score: -3.4
# Word: catastrophic, Sentiment Score: -2.2
# Word: cautious, Sentiment Score: -0.4
# Word: celebrate, Sentiment Score: 2.7
# Word: celebrated, Sentiment Score: 2.7
# Word: celebrates, Sentiment Score: 2.7
# Word: celebrating, Sentiment Score: 2.7
# Word: censor, Sentiment Score: -2.0
# Word: censored, Sentiment Score: -0.6
# Word: censors, Sentiment Score: -1.2
# Word: certain, Sentiment Score: 1.1
# Word: certainly, Sentiment Score: 1.4
# Word: certainties, Sentiment Score: 0.9
# Word: certainty, Sentiment Score: 1.0
# Word: chagrin, Sentiment Score: -1.9
# Word: chagrined, Sentiment Score: -1.4
# Word: challenge, Sentiment Score: 0.3
# Word: challenged, Sentiment Score: -0.4
# Word: challenger, Sentiment Score: 0.5
# Word: challengers, Sentiment Score: 0.4
# Word: challenges, Sentiment Score: 0.3
# Word: challenging, Sentiment Score: 0.6
# Word: challengingly, Sentiment Score: -0.6
# Word: champ, Sentiment Score: 2.1
# Word: champac, Sentiment Score: -0.2
# Word: champagne, Sentiment Score: 1.2
# Word: champagnes, Sentiment Score: 0.5
# Word: champaign, Sentiment Score: 0.2
# Word: champaigns, Sentiment Score: 0.5
# Word: champaks, Sentiment Score: -0.2
# Word: champed, Sentiment Score: 1.0
# Word: champer, Sentiment Score: -0.1
# Word: champers, Sentiment Score: 0.5
# Word: champerties, Sentiment Score: -0.1
# Word: champertous, Sentiment Score: 0.3
# Word: champerty, Sentiment Score: -0.2
# Word: champignon, Sentiment Score: 0.4
# ...
# Word: victimising, Sentiment Score: -2.5
# Word: victimization, Sentiment Score: -2.3
# Word: victimizations, Sentiment Score: -1.5
# Word: victimize, Sentiment Score: -2.5
# Word: victimized, Sentiment Score: -1.8
# Word: victimizer, Sentiment Score: -1.8
# Word: victimizers, Sentiment Score: -1.6
# Word: victimizes, Sentiment Score: -1.5
# Word: victimizing, Sentiment Score: -2.6
# Word: victimless, Sentiment Score: 0.6
# Word: victimologies, Sentiment Score: -0.6
# Word: victimologist, Sentiment Score: -0.5
# Word: victimologists, Sentiment Score: -0.4
# Word: victimology, Sentiment Score: 0.3
# Word: victims, Sentiment Score: -1.3
# Word: vigilant, Sentiment Score: 0.7
# Word: vigor, Sentiment Score: 1.1
# Word: vigorish, Sentiment Score: -0.4
# Word: vigorishes, Sentiment Score: 0.4
# Word: vigoroso, Sentiment Score: 1.5
# Word: vigorously, Sentiment Score: 0.5
# Word: vigorousness, Sentiment Score: 0.4
# Word: vigors, Sentiment Score: 1.0
# Word: vigour, Sentiment Score: 0.9
# Word: vigours, Sentiment Score: 0.4
# Word: vile, Sentiment Score: -3.1
# Word: villain, Sentiment Score: -2.6
# Word: villainess, Sentiment Score: -2.9
# Word: villainesses, Sentiment Score: -2.0
# Word: villainies, Sentiment Score: -2.3
# Word: villainous, Sentiment Score: -2.0
# Word: villainously, Sentiment Score: -2.9
# Word: villainousness, Sentiment Score: -2.7
# Word: villains, Sentiment Score: -3.4
# Word: villainy, Sentiment Score: -2.6
# Word: vindicate, Sentiment Score: 0.3
# Word: vindicated, Sentiment Score: 1.8
# Word: vindicates, Sentiment Score: 1.6
# Word: vindicating, Sentiment Score: -1.1
# Word: violate, Sentiment Score: -2.2
# Word: violated, Sentiment Score: -2.4
# Word: violater, Sentiment Score: -2.6
# Word: violaters, Sentiment Score: -2.4
# Word: violates, Sentiment Score: -2.3
# Word: violating, Sentiment Score: -2.5
# Word: violation, Sentiment Score: -2.2
# Word: violations, Sentiment Score: -2.4
# Word: violative, Sentiment Score: -2.4
# Word: violator, Sentiment Score: -2.4
# Word: violators, Sentiment Score: -1.9
# Word: violence, Sentiment Score: -3.1
# Word: violent, Sentiment Score: -2.9
# Word: violently, Sentiment Score: -2.8
# Word: virtue, Sentiment Score: 1.8
# Word: virtueless, Sentiment Score: -1.4
# Word: virtues, Sentiment Score: 1.5
# Word: virtuosa, Sentiment Score: 1.7
# Word: virtuosas, Sentiment Score: 1.8
# Word: virtuose, Sentiment Score: 1.0
# Word: virtuosi, Sentiment Score: 0.9
# Word: virtuosic, Sentiment Score: 2.2
# Word: virtuosity, Sentiment Score: 2.1
# Word: virtuoso, Sentiment Score: 2.0
# Word: virtuosos, Sentiment Score: 1.8
# Word: virtuous, Sentiment Score: 2.4
# Word: virtuously, Sentiment Score: 1.8
# Word: virtuousness, Sentiment Score: 2.0
# Word: virulent, Sentiment Score: -2.7
# Word: vision, Sentiment Score: 1.0
# Word: visionary, Sentiment Score: 2.4
# Word: visioning, Sentiment Score: 1.1
# Word: visions, Sentiment Score: 0.9
# Word: vital, Sentiment Score: 1.2
# Word: vitalise, Sentiment Score: 1.1
# Word: vitalised, Sentiment Score: 0.6
# Word: vitalises, Sentiment Score: 1.1
# Word: vitalising, Sentiment Score: 2.1
# Word: vitalism, Sentiment Score: 0.2
# Word: vitalist, Sentiment Score: 0.3
# Word: vitalists, Sentiment Score: 0.3
# Word: vitalities, Sentiment Score: 1.2
# Word: vitality, Sentiment Score: 1.3
# Word: vitalization, Sentiment Score: 1.6
# Word: vitalizations, Sentiment Score: 0.8
# Word: vitalize, Sentiment Score: 1.6
# Word: vitalized, Sentiment Score: 1.5
# Word: vitalizes, Sentiment Score: 1.4
# Word: vitalizing, Sentiment Score: 1.3
# Word: vitally, Sentiment Score: 1.1
# Word: vitals, Sentiment Score: 1.1
# Word: vitamin, Sentiment Score: 1.2
# Word: vitriolic, Sentiment Score: -2.1
# Word: vivacious, Sentiment Score: 1.8
# Word: vociferous, Sentiment Score: -0.8
# Word: vulnerabilities, Sentiment Score: -0.6
# Word: vulnerability, Sentiment Score: -0.9
# Word: vulnerable, Sentiment Score: -0.9
# Word: vulnerableness, Sentiment Score: -1.1
# Word: vulnerably, Sentiment Score: -1.2
# Word: vulture, Sentiment Score: -2.0
# Word: vultures, Sentiment Score: -1.3
# Word: w00t, Sentiment Score: 2.2
# Word: walkout, Sentiment Score: -1.3
# Word: walkouts, Sentiment Score: -0.7
# Word: wanker, Sentiment Score: -2.5
# Word: want, Sentiment Score: 0.3
# Word: war, Sentiment Score: -2.9
# Word: warfare, Sentiment Score: -1.2
# Word: warfares, Sentiment Score: -1.8
# Word: warm, Sentiment Score: 0.9
# Word: warmblooded, Sentiment Score: 0.2
# Word: warmed, Sentiment Score: 1.1
# Word: warmer, Sentiment Score: 1.2
# Word: warmers, Sentiment Score: 1.0
# Word: warmest, Sentiment Score: 1.7
# Word: warmhearted, Sentiment Score: 1.8
# Word: warmheartedness, Sentiment Score: 2.7
# Word: warming, Sentiment Score: 0.6
# Word: warmish, Sentiment Score: 1.4
# Word: warmly, Sentiment Score: 1.7
# Word: warmness, Sentiment Score: 1.5
# Word: warmonger, Sentiment Score: -2.9
# Word: warmongering, Sentiment Score: -2.5
# Word: warmongers, Sentiment Score: -2.8
# Word: warmouth, Sentiment Score: 0.4
# Word: warmouths, Sentiment Score: -0.8
# Word: warms, Sentiment Score: 1.1
# Word: warmth, Sentiment Score: 2.0
# Word: warmup, Sentiment Score: 0.4
# Word: warmups, Sentiment Score: 0.8
# Word: warn, Sentiment Score: -0.4
# Word: warned, Sentiment Score: -1.1
# Word: warning, Sentiment Score: -1.4
# Word: warnings, Sentiment Score: -1.2
# Word: warns, Sentiment Score: -0.4
# Word: warred, Sentiment Score: -2.4
# Word: warring, Sentiment Score: -1.9
# Word: wars, Sentiment Score: -2.6
# Word: warsaw, Sentiment Score: -0.1
# Word: warsaws, Sentiment Score: -0.2
# Word: warship, Sentiment Score: -0.7
# Word: warships, Sentiment Score: -0.5
# Word: warstle, Sentiment Score: 0.1
# Word: waste, Sentiment Score: -1.8
# Word: wasted, Sentiment Score: -2.2
# Word: wasting, Sentiment Score: -1.7
# Word: wavering, Sentiment Score: -0.6
# Word: weak, Sentiment Score: -1.9
# Word: weaken, Sentiment Score: -1.8
# Word: weakened, Sentiment Score: -1.3
# Word: weakener, Sentiment Score: -1.6
# Word: weakeners, Sentiment Score: -1.3
# Word: weakening, Sentiment Score: -1.3
# Word: weakens, Sentiment Score: -1.3
# Word: weaker, Sentiment Score: -1.9
# Word: weakest, Sentiment Score: -2.3
# Word: weakfish, Sentiment Score: -0.2
# Word: weakfishes, Sentiment Score: -0.6
# Word: weakhearted, Sentiment Score: -1.6
# Word: weakish, Sentiment Score: -1.2
# Word: weaklier, Sentiment Score: -1.5
# Word: weakliest, Sentiment Score: -2.1
# Word: weakling, Sentiment Score: -1.3
# Word: weaklings, Sentiment Score: -1.4
# Word: weakly, Sentiment Score: -1.8
# Word: weakness, Sentiment Score: -1.8
# Word: weaknesses, Sentiment Score: -1.5
# Word: weakside, Sentiment Score: -1.1
# Word: wealth, Sentiment Score: 2.2
# Word: wealthier, Sentiment Score: 2.2
# Word: wealthiest, Sentiment Score: 2.2
# Word: wealthily, Sentiment Score: 2.0
# Word: wealthiness, Sentiment Score: 2.4
# Word: wealthy, Sentiment Score: 1.5
# Word: weapon, Sentiment Score: -1.2
# Word: weaponed, Sentiment Score: -1.4
# Word: weaponless, Sentiment Score: 0.1
# Word: weaponry, Sentiment Score: -0.9
# Word: weapons, Sentiment Score: -1.9
# Word: weary, Sentiment Score: -1.1
# Word: weep, Sentiment Score: -2.7
# Word: weeper, Sentiment Score: -1.9
# Word: weepers, Sentiment Score: -1.1
# Word: weepie, Sentiment Score: -0.4
# Word: weepier, Sentiment Score: -1.8
# Word: weepies, Sentiment Score: -1.6
# Word: weepiest, Sentiment Score: -2.4
# Word: weeping, Sentiment Score: -1.9
# Word: weepings, Sentiment Score: -1.9
# Word: weeps, Sentiment Score: -1.4
# Word: weepy, Sentiment Score: -1.3
# Word: weird, Sentiment Score: -0.7
# Word: weirder, Sentiment Score: -0.5
# Word: weirdest, Sentiment Score: -0.9
# Word: weirdie, Sentiment Score: -1.3
# Word: weirdies, Sentiment Score: -1.0
# Word: weirdly, Sentiment Score: -1.2
# Word: weirdness, Sentiment Score: -0.9
# Word: weirdnesses, Sentiment Score: -0.7
# Word: weirdo, Sentiment Score: -1.8
# Word: weirdoes, Sentiment Score: -1.3
# Word: weirdos, Sentiment Score: -1.1
# Word: weirds, Sentiment Score: -0.6
# Word: weirdy, Sentiment Score: -0.9
# Word: welcome, Sentiment Score: 2.0
# Word: welcomed, Sentiment Score: 1.4
# Word: welcomely, Sentiment Score: 1.9
# Word: welcomeness, Sentiment Score: 2.0
# Word: welcomer, Sentiment Score: 1.4
# Word: welcomers, Sentiment Score: 1.9
# Word: welcomes, Sentiment Score: 1.7
# Word: welcoming, Sentiment Score: 1.9
# Word: well, Sentiment Score: 1.1
# Word: welladay, Sentiment Score: 0.3
# Word: wellaway, Sentiment Score: -0.8
# Word: wellborn, Sentiment Score: 1.8
# Word: welldoer, Sentiment Score: 2.5
# Word: welldoers, Sentiment Score: 1.6
# Word: welled, Sentiment Score: 0.4
# Word: wellhead, Sentiment Score: 0.1
# Word: wellheads, Sentiment Score: 0.5
# Word: wellhole, Sentiment Score: -0.1
# Word: wellies, Sentiment Score: 0.4
# Word: welling, Sentiment Score: 1.6
# Word: wellness, Sentiment Score: 1.9
# Word: wells, Sentiment Score: 1.0
# Word: wellsite, Sentiment Score: 0.5
# Word: wellspring, Sentiment Score: 1.5
# Word: wellsprings, Sentiment Score: 1.4
# Word: welly, Sentiment Score: 0.2
# Word: wept, Sentiment Score: -2.0
# Word: whimsical, Sentiment Score: 0.3
# Word: whine, Sentiment Score: -1.5
# Word: whined, Sentiment Score: -0.9
# Word: whiner, Sentiment Score: -1.2
# Word: whiners, Sentiment Score: -0.6
# Word: whines, Sentiment Score: -1.8
# Word: whiney, Sentiment Score: -1.3
# Word: whining, Sentiment Score: -0.9
# Word: whitewash, Sentiment Score: 0.1
# Word: whore, Sentiment Score: -3.3
# Word: whored, Sentiment Score: -2.8
# Word: whoredom, Sentiment Score: -2.1
# Word: whoredoms, Sentiment Score: -2.4
# Word: whorehouse, Sentiment Score: -1.1
# Word: whorehouses, Sentiment Score: -1.9
# Word: whoremaster, Sentiment Score: -1.9
# Word: whoremasters, Sentiment Score: -1.5
# Word: whoremonger, Sentiment Score: -2.6
# Word: whoremongers, Sentiment Score: -2.0
# Word: whores, Sentiment Score: -3.0
# Word: whoreson, Sentiment Score: -2.2
# Word: whoresons, Sentiment Score: -2.5
# Word: wicked, Sentiment Score: -2.4
# Word: wickeder, Sentiment Score: -2.2
# Word: wickedest, Sentiment Score: -2.9
# Word: wickedly, Sentiment Score: -2.1
# Word: wickedness, Sentiment Score: -2.1
# Word: wickednesses, Sentiment Score: -2.2
# Word: widowed, Sentiment Score: -2.1
# Word: willingness, Sentiment Score: 1.1
# Word: wimp, Sentiment Score: -1.4
# Word: wimpier, Sentiment Score: -1.0
# Word: wimpiest, Sentiment Score: -0.9
# Word: wimpiness, Sentiment Score: -1.2
# Word: wimpish, Sentiment Score: -1.6
# Word: wimpishness, Sentiment Score: -0.2
# Word: wimple, Sentiment Score: -0.2
# Word: wimples, Sentiment Score: -0.3
# Word: wimps, Sentiment Score: -1.0
# Word: wimpy, Sentiment Score: -0.9
# Word: win, Sentiment Score: 2.8
# Word: winnable, Sentiment Score: 1.8
# Word: winned, Sentiment Score: 1.8
# Word: winner, Sentiment Score: 2.8
# Word: winners, Sentiment Score: 2.1
# Word: winning, Sentiment Score: 2.4
# Word: winningly, Sentiment Score: 2.3
# Word: winnings, Sentiment Score: 2.5
# Word: winnow, Sentiment Score: -0.3
# Word: winnower, Sentiment Score: -0.1
# Word: winnowers, Sentiment Score: -0.2
# Word: winnowing, Sentiment Score: -0.1
# Word: winnows, Sentiment Score: -0.2
# Word: wins, Sentiment Score: 2.7
# Word: wisdom, Sentiment Score: 2.4
# Word: wise, Sentiment Score: 2.1
# Word: wiseacre, Sentiment Score: -1.2
# Word: wiseacres, Sentiment Score: -0.1
# Word: wiseass, Sentiment Score: -1.8
# Word: wiseasses, Sentiment Score: -1.5
# Word: wisecrack, Sentiment Score: -0.1
# Word: wisecracked, Sentiment Score: -0.5
# Word: wisecracker, Sentiment Score: -0.1
# Word: wisecrackers, Sentiment Score: 0.1
# Word: wisecracking, Sentiment Score: -0.6
# Word: wisecracks, Sentiment Score: -0.3
# Word: wised, Sentiment Score: 1.5
# Word: wiseguys, Sentiment Score: 0.3
# Word: wiselier, Sentiment Score: 0.9
# Word: wiseliest, Sentiment Score: 1.6
# Word: wisely, Sentiment Score: 1.8
# Word: wiseness, Sentiment Score: 1.9
# Word: wisenheimer, Sentiment Score: -1.0
# Word: wisenheimers, Sentiment Score: -1.4
# Word: wisents, Sentiment Score: 0.4
# Word: wiser, Sentiment Score: 1.2
# Word: wises, Sentiment Score: 1.3
# Word: wisest, Sentiment Score: 2.1
# Word: wisewomen, Sentiment Score: 1.3
# Word: wish, Sentiment Score: 1.7
# Word: wishes, Sentiment Score: 0.6
# Word: wishing, Sentiment Score: 0.9
# Word: witch, Sentiment Score: -1.5
# Word: withdrawal, Sentiment Score: 0.1
# Word: woe, Sentiment Score: -1.8
# Word: woebegone, Sentiment Score: -2.6
# Word: woebegoneness, Sentiment Score: -1.1
# Word: woeful, Sentiment Score: -1.9
# Word: woefully, Sentiment Score: -1.7
# Word: woefulness, Sentiment Score: -2.1
# Word: woes, Sentiment Score: -1.9
# Word: woesome, Sentiment Score: -1.2
# Word: won, Sentiment Score: 2.7
# Word: wonderful, Sentiment Score: 2.7
# Word: wonderfully, Sentiment Score: 2.9
# Word: wonderfulness, Sentiment Score: 2.9
# Word: woo, Sentiment Score: 2.1
# Word: woohoo, Sentiment Score: 2.3
# Word: woot, Sentiment Score: 1.8
# Word: worn, Sentiment Score: -1.2
# Word: worried, Sentiment Score: -1.2
# Word: worriedly, Sentiment Score: -2.0
# Word: worrier, Sentiment Score: -1.8
# Word: worriers, Sentiment Score: -1.7
# Word: worries, Sentiment Score: -1.8
# Word: worriment, Sentiment Score: -1.5
# Word: worriments, Sentiment Score: -1.9
# Word: worrisome, Sentiment Score: -1.7
# Word: worrisomely, Sentiment Score: -2.0
# Word: worrisomeness, Sentiment Score: -1.9
# Word: worrit, Sentiment Score: -2.1
# Word: worrits, Sentiment Score: -1.2
# Word: worry, Sentiment Score: -1.9
# Word: worrying, Sentiment Score: -1.4
# Word: worrywart, Sentiment Score: -1.8
# Word: worrywarts, Sentiment Score: -1.5
# Word: worse, Sentiment Score: -2.1
# Word: worsen, Sentiment Score: -2.3
# Word: worsened, Sentiment Score: -1.9
# Word: worsening, Sentiment Score: -2.0
# Word: worsens, Sentiment Score: -2.1
# Word: worser, Sentiment Score: -2.0
# Word: worship, Sentiment Score: 1.2
# Word: worshiped, Sentiment Score: 2.4
# Word: worshiper, Sentiment Score: 1.0
# Word: worshipers, Sentiment Score: 0.9
# Word: worshipful, Sentiment Score: 0.7
# Word: worshipfully, Sentiment Score: 1.1
# Word: worshipfulness, Sentiment Score: 1.6
# Word: worshiping, Sentiment Score: 1.0
# Word: worshipless, Sentiment Score: -0.6
# Word: worshipped, Sentiment Score: 2.7
# Word: worshipper, Sentiment Score: 0.6
# Word: worshippers, Sentiment Score: 0.8
# Word: worshipping, Sentiment Score: 1.6
# Word: worships, Sentiment Score: 1.4
# Word: worst, Sentiment Score: -3.1
# Word: worth, Sentiment Score: 0.9
# Word: worthless, Sentiment Score: -1.9
# Word: worthwhile, Sentiment Score: 1.4
# Word: worthy, Sentiment Score: 1.9
# Word: wow, Sentiment Score: 2.8
# Word: wowed, Sentiment Score: 2.6
# Word: wowing, Sentiment Score: 2.5
# Word: wows, Sentiment Score: 2.0
# Word: wowser, Sentiment Score: -1.1
# Word: wowsers, Sentiment Score: 1.0
# Word: wrathful, Sentiment Score: -2.7
# Word: wreck, Sentiment Score: -1.9
# Word: wrong, Sentiment Score: -2.1
# Word: wronged, Sentiment Score: -1.9
# Word: yay, Sentiment Score: 2.4
# Word: yeah, Sentiment Score: 1.2
# Word: yearning, Sentiment Score: 0.5
# Word: yeees, Sentiment Score: 1.7
# Word: yep, Sentiment Score: 1.2
# Word: yes, Sentiment Score: 1.7
# Word: youthful, Sentiment Score: 1.3
# Word: yucky, Sentiment Score: -1.8
# Word: yummy, Sentiment Score: 2.4
# Word: zealot, Sentiment Score: -1.9
# Word: zealots, Sentiment Score: -0.8
# Word: zealous, Sentiment Score: 0.5
# Word: {:, Sentiment Score: 1.8
# Word: |-0, Sentiment Score: -1.2
# Word: |-:, Sentiment Score: -0.8
# Word: |-:>, Sentiment Score: -1.6
# Word: |-o, Sentiment Score: -1.2
# Word: |:, Sentiment Score: -0.5
# Word: |;-), Sentiment Score: 2.2
# Word: |=, Sentiment Score: -0.4
# Word: |^:, Sentiment Score: -1.1
# Word: |o:, Sentiment Score: -0.9
# Word: ||-:, Sentiment Score: -2.3
# Word: }:, Sentiment Score: -2.1
# Word: }:(, Sentiment Score: -2.0
# Word: }:), Sentiment Score: 0.4
# Word: }:-(, Sentiment Score: -2.1
# Word: }:-), Sentiment Score: 0.3
# Word: unplayable, Sentiment Score: -4.0
# Word: 10/10, Sentiment Score: 2
# Word: bad devs, Sentiment Score: -4.0
# Word: FIX AUDIO, Sentiment Score: -4.0
# Word: trash, Sentiment Score: -4.0
# Word: this game gets worse and worse, Sentiment Score: -4.0
# Word: super inconsistent, Sentiment Score: -4.0
# Word: Best battle royale game, Sentiment Score: 4
# Word: Probably the most fun i've ever had out of a battle royale, Sentiment Score: 4
# Word: best battle royale games, Sentiment Score: 4
# Word: pog, Sentiment Score: 3.8
# Word: gem, Sentiment Score: 4
# Word: Despite all bugs and glitches, Sentiment Score: 0
# Word: Dogshit, Sentiment Score: -4.0
# Word: bugs, Sentiment Score: -4.0

# %%
ow2_5topics.iloc[24, ow2_5topics.columns.get_loc("voted_up")] = 0.0
print(ow2_5topics.iloc[24])
ow2_5topics.iloc[13, ow2_5topics.columns.get_loc("voted_up")] = 0.0
print(ow2_5topics.iloc[13])
ow2_5topics.iloc[75, ow2_5topics.columns.get_loc("voted_up")] = 0.0
print(ow2_5topics.iloc[175])
# Out:
# Unnamed: 0                                                                  24
# language                                                               english
# review                       All the baseline stuff is good, but its crazy ...
# timestamp_updated                                                   2023-12-06
# voted_up                                                                   0.0
# comment_count                                                                0
# author.steamid                                               76561198146936905
# author.playtime_at_review                                                 20.1
# bigram_review                ['baseline_stuff', 'stuff_crazy', 'crazy_devel...
# trigram_review               ['baseline_stuff_crazy', 'stuff_crazy_develope...
# Topic                                                                Developer
# Name                         14_developer_developer developer_developer suc...
# Representation               ['developer', 'developer developer', 'develope...
# Representative_Docs          ['fuck developer', 'bad developer team', 'hate...
# Top_n_words                  developer - developer developer - developer su...
# Probability                                                           0.347263
# Representative_document                                                  False
# Name: 24, dtype: object
# Unnamed: 0                                                                  13
# language                                                               english
# review                       they change the color of old skins and charge ...
# timestamp_updated                                                   2024-02-21
# voted_up                                                                   0.0
# comment_count                                                                0
# author.steamid                                               76561199003199600
# author.playtime_at_review                                           364.316667
# bigram_review                ['change_color', 'color_old', 'old_skin', 'ski...
# trigram_review               ['change_color_old', 'color_old_skin', 'old_sk...
# Topic                                                                Expensive
# Name                                           9_skin_price_buy skin_expensive
# Representation               ['skin', 'price', 'buy skin', 'expensive', 'we...
# Representative_Docs          ['change color old skin charge dollars also ma...
# Top_n_words                  skin - price - buy skin - expensive - weapon s...
# Probability                                                           0.277365
# Representative_document                                                  False
# Name: 13, dtype: object
# Unnamed: 0                                                                 175
# language                                                               english
# review                       dont touch this dogshit game, the matchmaking ...
# timestamp_updated                                                   2024-01-11
# voted_up                                                                   0.0
# comment_count                                                                0
# author.steamid                                               76561198160655896
# author.playtime_at_review                                                 61.2
# bigram_review                ['dont_touch', 'touch_dogshit', 'dogshit_match...
# trigram_review               ['dont_touch_dogshit', 'touch_dogshit_matchmak...
# Topic                                                              Matchmaking
# Name                         7_matchmaking_worst matchmaking_worst_matchmak...
# Representation               ['matchmaking', 'worst matchmaking', 'worst', ...
# Representative_Docs          ['worst matchmaking ame', 'worst matchmaking',...
# Top_n_words                  matchmaking - worst matchmaking - worst - matc...
# Probability                                                           0.303632
# Representative_document                                                  False
# Name: 175, dtype: object

# %%
ow2_5topics['compound_sentiment'] = ow2_5topics['review'].map(lambda x: analyzer.polarity_scores(x)['compound'])
ow2_5topics
# Out:
#      Unnamed: 0 language                                             review  \
# 0             0  english  This really is a game that is not good for you...
# 1             1  english  got almost 900 hours, its a good game but want...
# 2             2  english  The skins are good.\nThey cost too much. \n\nB...
# 3             3  english  this game is horrible i load into any round an...
# 4             4  english  I bought the game and after its transition to ...
# ..          ...      ...                                                ...
# 850         850  english              devs have no idea what they are doing
# 851         851  english              Send the devs to the pits or Tartarus
# 852         852  english           k its kinda good but the devs still suck
# 853         853  english  Devs decide to make every worst decision possible
# 854         854  english  i cannot fathom my hatred towards the hero kno...
#
#     timestamp_updated  voted_up  comment_count     author.steamid  \
# 0          2023-10-16       0.0              8  76561198426916437
# 1          2024-07-10       0.0              0  76561198413080751
# 2          2024-06-21       0.0              1  76561198101681894
# 3          2024-01-08       0.0              0  76561198304704423
# 4          2023-08-21       1.0              1  76561198189115163
# ..                ...       ...            ...                ...
# 850        2024-01-29       0.0              0  76561198400880182
# 851        2024-09-26       0.0              0  76561198997284040
# 852        2024-08-11       0.0              0  76561199075842133
# 853        2024-09-18       0.0              0  76561199092812470
# 854        2024-09-02       0.0              0  76561199524199237
#
#      author.playtime_at_review  \
# 0                     5.066667
# 1                    86.166667
# 2                   355.000000
# 3                    25.266667
# 4                    31.133333
# ..                         ...
# 850                  21.433333
# 851                 250.450000
# 852                   6.350000
# 853                   4.616667
# 854                  28.250000
#
#                                          bigram_review  \
# 0    ['really_mental', 'mental_health', 'health_mat...
# 1    ['get_almost', 'almost_hours', 'hours_want', '...
# 2    ['skin_cost', 'cost_much', 'much_want', 'want_...
# 3    ['horrible_load', 'load_round', 'round_get', '...
# 4    ['buy_transition', 'transition_free', 'free_ge...
# ..                                                 ...
# 850                                 ['developer_idea']
# 851  ['send_developer', 'developer_pit', 'pit_tarta...
# 852  ['kinda_developer', 'developer_still', 'still_...
# 853  ['developer_decide', 'decide_make', 'make_ever...
# 854  ['cannot_fathom', 'fathom_hatred', 'hatred_tow...
#
#                                         trigram_review        Topic  \
# 0    ['really_mental_health', 'mental_health_matchm...  Matchmaking
# 1    ['get_almost_hours', 'almost_hours_want', 'hou...    Expensive
# 2    ['skin_cost_much', 'cost_much_want', 'much_wan...    Expensive
# 3    ['horrible_load_round', 'load_round_get', 'rou...       Sombra
# 4    ['buy_transition_free', 'transition_free_get',...    Expensive
# ..                                                 ...          ...
# 850                                                 []    Developer
# 851   ['send_developer_pit', 'developer_pit_tartarus']    Developer
# 852  ['kinda_developer_still', 'developer_still_suck']    Developer
# 853  ['developer_decide_make', 'decide_make_every',...    Developer
# 854  ['cannot_fathom_hatred', 'fathom_hatred_toward...       Sombra
#
#                                                   Name  \
# 0    7_matchmaking_worst matchmaking_worst_matchmak...
# 1                      9_skin_price_buy skin_expensive
# 2                      9_skin_price_buy skin_expensive
# 3    11_sombra_remove sombra_sombra remove sombra_s...
# 4                      9_skin_price_buy skin_expensive
# ..                                                 ...
# 850  14_developer_developer developer_developer suc...
# 851  14_developer_developer developer_developer suc...
# 852  14_developer_developer developer_developer suc...
# 853  14_developer_developer developer_developer suc...
# 854  11_sombra_remove sombra_sombra remove sombra_s...
#
#                                         Representation  \
# 0    ['matchmaking', 'worst matchmaking', 'worst', ...
# 1    ['skin', 'price', 'buy skin', 'expensive', 'we...
# 2    ['skin', 'price', 'buy skin', 'expensive', 'we...
# 3    ['sombra', 'remove sombra', 'sombra remove som...
# 4    ['skin', 'price', 'buy skin', 'expensive', 'we...
# ..                                                 ...
# 850  ['developer', 'developer developer', 'develope...
# 851  ['developer', 'developer developer', 'develope...
# 852  ['developer', 'developer developer', 'develope...
# 853  ['developer', 'developer developer', 'develope...
# 854  ['sombra', 'remove sombra', 'sombra remove som...
#
#                                    Representative_Docs  \
# 0    ['worst matchmaking ame', 'worst matchmaking',...
# 1    ['change color old skin charge dollars also ma...
# 2    ['change color old skin charge dollars also ma...
# 3      ['sombra hate', 'sombra still', 'sombra still']
# 4    ['change color old skin charge dollars also ma...
# ..                                                 ...
# 850  ['fuck developer', 'bad developer team', 'hate...
# 851  ['fuck developer', 'bad developer team', 'hate...
# 852  ['fuck developer', 'bad developer team', 'hate...
# 853  ['fuck developer', 'bad developer team', 'hate...
# 854    ['sombra hate', 'sombra still', 'sombra still']
#
#                                            Top_n_words  Probability  \
# 0    matchmaking - worst matchmaking - worst - matc...     1.000000
# 1    skin - price - buy skin - expensive - weapon s...     0.230906
# 2    skin - price - buy skin - expensive - weapon s...     0.226672
# 3    sombra - remove sombra - sombra remove sombra ...     0.241103
# 4    skin - price - buy skin - expensive - weapon s...     0.448012
# ..                                                 ...          ...
# 850  developer - developer developer - developer su...     0.655505
# 851  developer - developer developer - developer su...     0.664034
# 852  developer - developer developer - developer su...     0.500184
# 853  developer - developer developer - developer su...     0.283244
# 854  sombra - remove sombra - sombra remove sombra ...     0.383751
#
#      Representative_document  compound_sentiment
# 0                      False             -0.3412
# 1                      False              0.6111
# 2                      False              0.2500
# 3                      False              0.3612
# 4                      False              0.8172
# ..                       ...                 ...
# 850                    False             -0.2960
# 851                    False              0.0000
# 852                    False             -0.4672
# 853                    False             -0.6249
# 854                    False              0.3753
#
# [855 rows x 18 columns]

# %%
# ow2_5topics.head()

# # keep Topic 
# # remove Name, steamid, bigram_review, trigram_review, language, unnamed: 0, probability  

ow2_5topics.drop(['Name', 'bigram_review', 'trigram_review', 'language', 'Unnamed: 0'], axis=1, inplace=True)
ow2_5topics.head()
# Out:
#                                               review timestamp_updated  \
# 0  This really is a game that is not good for you...        2023-10-16
# 1  got almost 900 hours, its a good game but want...        2024-07-10
# 2  The skins are good.\nThey cost too much. \n\nB...        2024-06-21
# 3  this game is horrible i load into any round an...        2024-01-08
# 4  I bought the game and after its transition to ...        2023-08-21
#
#    voted_up  comment_count     author.steamid  author.playtime_at_review  \
# 0       0.0              8  76561198426916437                   5.066667
# 1       0.0              0  76561198413080751                  86.166667
# 2       0.0              1  76561198101681894                 355.000000
# 3       0.0              0  76561198304704423                  25.266667
# 4       1.0              1  76561198189115163                  31.133333
#
#          Topic                                     Representation  \
# 0  Matchmaking  ['matchmaking', 'worst matchmaking', 'worst', ...
# 1    Expensive  ['skin', 'price', 'buy skin', 'expensive', 'we...
# 2    Expensive  ['skin', 'price', 'buy skin', 'expensive', 'we...
# 3       Sombra  ['sombra', 'remove sombra', 'sombra remove som...
# 4    Expensive  ['skin', 'price', 'buy skin', 'expensive', 'we...
#
#                                  Representative_Docs  \
# 0  ['worst matchmaking ame', 'worst matchmaking',...
# 1  ['change color old skin charge dollars also ma...
# 2  ['change color old skin charge dollars also ma...
# 3    ['sombra hate', 'sombra still', 'sombra still']
# 4  ['change color old skin charge dollars also ma...
#
#                                          Top_n_words  Probability  \
# 0  matchmaking - worst matchmaking - worst - matc...     1.000000
# 1  skin - price - buy skin - expensive - weapon s...     0.230906
# 2  skin - price - buy skin - expensive - weapon s...     0.226672
# 3  sombra - remove sombra - sombra remove sombra ...     0.241103
# 4  skin - price - buy skin - expensive - weapon s...     0.448012
#
#    Representative_document  compound_sentiment
# 0                    False             -0.3412
# 1                    False              0.6111
# 2                    False              0.2500
# 3                    False              0.3612
# 4                    False              0.8172

# %%
print(ow2_5topics['review'].iloc[2])
print(ow2_5topics['voted_up'].iloc[2])
print(ow2_5topics['compound_sentiment'].iloc[2])
# Out:
# The skins are good.
# They cost too much.
#
# Blizzard wants to empty your wallet in any way possible.
# Balancing sucks.
#
# I only play this game because there's nothing else to replace it currently.
# 0.0
# 0.25

# %%
def compound_recommened(compound_sentiment):
    if compound_sentiment >= 0.0:
        return 1.0
    elif compound_sentiment < 0.0:
        return 0.0

# %%
ow2_5topics['compound_recommended'] = ow2_5topics['compound_sentiment'].map(lambda x: compound_recommened(x))

# %%
ow2_5topics[ow2_5topics['voted_up'] == 0.0].head(30)
# Out:
#                                                review timestamp_updated  \
# 0   This really is a game that is not good for you...        2023-10-16
# 1   got almost 900 hours, its a good game but want...        2024-07-10
# 2   The skins are good.\nThey cost too much. \n\nB...        2024-06-21
# 3   this game is horrible i load into any round an...        2024-01-08
# 5   don't you love it when a game FORCES you to be...        2023-10-01
# 7   For Blizzard, the game doesn't matter. For Bli...        2024-09-14
# 8   The game is ok. It's been ruined by aggressive...        2024-03-10
# 9    The matching system is horrible. If you care ...        2024-10-10
# 11  They lie, cheat, cover up and flat out break p...        2024-07-25
# 12  Worst Matchmaking in the history of games. You...        2024-03-29
# 13  they change the color of old skins and charge ...        2024-02-21
# 14  as much i used to love the game the devs kille...        2023-11-23
# 16  Its almost been a year since release of this g...        2023-08-19
# 17  The worst matchmaking that has ever had an onl...        2023-08-14
# 18  I swear a group of monkeys could balance this ...        2023-08-12
# 19  I absolutely LOVED this game and to an extent ...        2023-08-11
# 21  Remove sombra and Zarya then i will actually b...        2024-05-28
# 22  It's hard. the game is good... And it is free ...        2023-08-25
# 23  this game is very fortnite like game would rec...        2023-08-16
# 24  All the baseline stuff is good, but its crazy ...        2023-12-06
# 26  Matchmaking is atrocious, almost as if it trie...        2024-06-22
# 28  worst game in fucking history, terrible match ...        2023-11-13
# 29  Terrible game with terrible matchmaking.\n\nEv...        2023-08-14
# 30  Blizzard: oh i have an idea lets give a charac...        2024-07-13
# 31  A "complete rehaul" of OW1 and it plays exactl...        2024-09-26
# 32  This game sucks so much\n\nedit: games matchma...        2023-12-06
# 33  OW1 was perfect the way it was. We bought it. ...        2024-03-30
# 34  I have more time on console but that doesn't m...        2024-08-28
# 38  For beginners, it's really hard, I've lost abo...        2024-10-15
# 41  A great game with great matchmaking. After pla...        2024-10-06
#
#     voted_up  comment_count     author.steamid  author.playtime_at_review  \
# 0        0.0              8  76561198426916437                   5.066667
# 1        0.0              0  76561198413080751                  86.166667
# 2        0.0              1  76561198101681894                 355.000000
# 3        0.0              0  76561198304704423                  25.266667
# 5        0.0              0  76561198268232003                   7.983333
# 7        0.0              0  76561198119351750                 443.033333
# 8        0.0              0  76561198066103181                  13.216667
# 9        0.0              0  76561198800947459                  14.416667
# 11       0.0              0  76561198308153956                  15.316667
# 12       0.0              0  76561199096911219                 146.566667
# 13       0.0              0  76561199003199600                 364.316667
# 14       0.0              0  76561198345957569                  13.850000
# 16       0.0              0  76561198150192228                   9.333333
# 17       0.0              0  76561199289399394                  21.950000
# 18       0.0              0  76561198120646299                   4.516667
# 19       0.0              0  76561199031132027                   8.300000
# 21       0.0              0  76561199185108883                  53.850000
# 22       0.0              0  76561198007356142                   4.150000
# 23       0.0              0  76561198283225935                  20.133333
# 24       0.0              0  76561198146936905                  20.100000
# 26       0.0              0  76561198048912939                  12.266667
# 28       0.0              0  76561199116418057                 316.666667
# 29       0.0              0  76561198186787945                   4.183333
# 30       0.0              0  76561199043120560                  45.116667
# 31       0.0              0  76561198047897603                  17.966667
# 32       0.0              0  76561198833754596                  43.250000
# 33       0.0              0  76561198009779624                  11.766667
# 34       0.0              1  76561198400856636                   7.766667
# 38       0.0              0  76561198819417488                   4.850000
# 41       0.0              0  76561198073794575                  73.833333
#
#              Topic                                     Representation  \
# 0      Matchmaking  ['matchmaking', 'worst matchmaking', 'worst', ...
# 1        Expensive  ['skin', 'price', 'buy skin', 'expensive', 'we...
# 2        Expensive  ['skin', 'price', 'buy skin', 'expensive', 'we...
# 3           Sombra  ['sombra', 'remove sombra', 'sombra remove som...
# 5        Developer  ['developer', 'developer developer', 'develope...
# 7        Expensive  ['skin', 'price', 'buy skin', 'expensive', 'we...
# 8   Failed Promise  ['promise', 'break promise', 'deliver', 'promi...
# 9      Matchmaking  ['matchmaking', 'worst matchmaking', 'worst', ...
# 11  Failed Promise  ['promise', 'break promise', 'deliver', 'promi...
# 12     Matchmaking  ['matchmaking', 'worst matchmaking', 'worst', ...
# 13       Expensive  ['skin', 'price', 'buy skin', 'expensive', 'we...
# 14       Developer  ['developer', 'developer developer', 'develope...
# 16       Expensive  ['skin', 'price', 'buy skin', 'expensive', 'we...
# 17     Matchmaking  ['matchmaking', 'worst matchmaking', 'worst', ...
# 18  Failed Promise  ['promise', 'break promise', 'deliver', 'promi...
# 19       Developer  ['developer', 'developer developer', 'develope...
# 21          Sombra  ['sombra', 'remove sombra', 'sombra remove som...
# 22       Expensive  ['skin', 'price', 'buy skin', 'expensive', 'we...
# 23       Developer  ['developer', 'developer developer', 'develope...
# 24       Developer  ['developer', 'developer developer', 'develope...
# 26     Matchmaking  ['matchmaking', 'worst matchmaking', 'worst', ...
# 28     Matchmaking  ['matchmaking', 'worst matchmaking', 'worst', ...
# 29     Matchmaking  ['matchmaking', 'worst matchmaking', 'worst', ...
# 30          Sombra  ['sombra', 'remove sombra', 'sombra remove som...
# 31       Expensive  ['skin', 'price', 'buy skin', 'expensive', 'we...
# 32     Matchmaking  ['matchmaking', 'worst matchmaking', 'worst', ...
# 33       Expensive  ['skin', 'price', 'buy skin', 'expensive', 'we...
# 34          Sombra  ['sombra', 'remove sombra', 'sombra remove som...
# 38     Matchmaking  ['matchmaking', 'worst matchmaking', 'worst', ...
# 41     Matchmaking  ['matchmaking', 'worst matchmaking', 'worst', ...
#
#                                   Representative_Docs  \
# 0   ['worst matchmaking ame', 'worst matchmaking',...
# 1   ['change color old skin charge dollars also ma...
# 2   ['change color old skin charge dollars also ma...
# 3     ['sombra hate', 'sombra still', 'sombra still']
# 5   ['fuck developer', 'bad developer team', 'hate...
# 7   ['change color old skin charge dollars also ma...
# 8           ['bad promise', 'promise', 'two promise']
# 9   ['worst matchmaking ame', 'worst matchmaking',...
# 11          ['bad promise', 'promise', 'two promise']
# 12  ['worst matchmaking ame', 'worst matchmaking',...
# 13  ['change color old skin charge dollars also ma...
# 14  ['fuck developer', 'bad developer team', 'hate...
# 16  ['change color old skin charge dollars also ma...
# 17  ['worst matchmaking ame', 'worst matchmaking',...
# 18          ['bad promise', 'promise', 'two promise']
# 19  ['fuck developer', 'bad developer team', 'hate...
# 21    ['sombra hate', 'sombra still', 'sombra still']
# 22  ['change color old skin charge dollars also ma...
# 23  ['fuck developer', 'bad developer team', 'hate...
# 24  ['fuck developer', 'bad developer team', 'hate...
# 26  ['worst matchmaking ame', 'worst matchmaking',...
# 28  ['worst matchmaking ame', 'worst matchmaking',...
# 29  ['worst matchmaking ame', 'worst matchmaking',...
# 30    ['sombra hate', 'sombra still', 'sombra still']
# 31  ['change color old skin charge dollars also ma...
# 32  ['worst matchmaking ame', 'worst matchmaking',...
# 33  ['change color old skin charge dollars also ma...
# 34    ['sombra hate', 'sombra still', 'sombra still']
# 38  ['worst matchmaking ame', 'worst matchmaking',...
# 41  ['worst matchmaking ame', 'worst matchmaking',...
#
#                                           Top_n_words  Probability  \
# 0   matchmaking - worst matchmaking - worst - matc...     1.000000
# 1   skin - price - buy skin - expensive - weapon s...     0.230906
# 2   skin - price - buy skin - expensive - weapon s...     0.226672
# 3   sombra - remove sombra - sombra remove sombra ...     0.241103
# 5   developer - developer developer - developer su...     0.291783
# 7   skin - price - buy skin - expensive - weapon s...     0.604222
# 8   promise - break promise - deliver - promise st...     0.022728
# 9   matchmaking - worst matchmaking - worst - matc...     1.000000
# 11  promise - break promise - deliver - promise st...     0.203708
# 12  matchmaking - worst matchmaking - worst - matc...     0.387737
# 13  skin - price - buy skin - expensive - weapon s...     0.277365
# 14  developer - developer developer - developer su...     0.394457
# 16  skin - price - buy skin - expensive - weapon s...     0.249552
# 17  matchmaking - worst matchmaking - worst - matc...     0.460956
# 18  promise - break promise - deliver - promise st...     0.250139
# 19  developer - developer developer - developer su...     0.402076
# 21  sombra - remove sombra - sombra remove sombra ...     0.229080
# 22  skin - price - buy skin - expensive - weapon s...     0.382264
# 23  developer - developer developer - developer su...     0.506000
# 24  developer - developer developer - developer su...     0.347263
# 26  matchmaking - worst matchmaking - worst - matc...     0.462343
# 28  matchmaking - worst matchmaking - worst - matc...     0.349390
# 29  matchmaking - worst matchmaking - worst - matc...     0.622410
# 30  sombra - remove sombra - sombra remove sombra ...     0.830009
# 31  skin - price - buy skin - expensive - weapon s...     0.225091
# 32  matchmaking - worst matchmaking - worst - matc...     0.403022
# 33  skin - price - buy skin - expensive - weapon s...     0.362046
# 34  sombra - remove sombra - sombra remove sombra ...     0.242509
# 38  matchmaking - worst matchmaking - worst - matc...     0.235517
# 41  matchmaking - worst matchmaking - worst - matc...     0.238368
#
#     Representative_document  compound_sentiment  compound_recommended
# 0                     False             -0.3412                   0.0
# 1                     False              0.6111                   1.0
# 2                     False              0.2500                   1.0
# 3                     False              0.3612                   1.0
# 5                     False             -0.8699                   0.0
# 7                     False             -0.4721                   0.0
# 8                     False             -0.2732                   0.0
# 9                     False             -0.3261                   0.0
# 11                    False              0.4003                   1.0
# 12                    False             -0.6384                   0.0
# 13                    False              0.2799                   1.0
# 14                    False              0.4927                   1.0
# 16                    False             -0.3818                   0.0
# 17                    False             -0.1531                   0.0
# 18                    False              0.2944                   1.0
# 19                    False              0.7176                   1.0
# 21                    False              0.5803                   1.0
# 22                    False             -0.1406                   0.0
# 23                    False             -0.2782                   0.0
# 24                    False             -0.8873                   0.0
# 26                    False             -0.9618                   0.0
# 28                    False             -0.9573                   0.0
# 29                    False             -0.8509                   0.0
# 30                    False             -0.2500                   0.0
# 31                    False              0.6249                   1.0
# 32                    False              0.1076                   1.0
# 33                    False              0.8126                   1.0
# 34                    False              0.6800                   1.0
# 38                    False              0.6970                   1.0
# 41                    False              0.8750                   1.0

# %% [markdown]
# This should be a negative sentiment, but VADER gave it as a positive one as it has words such as great, work which makes it positive

# %% [markdown]
# ## Word Play
# Some of the sentiments are misclassified as positive even though it is negative and vice versa. One example is as shown below:-
# Reasons could be VADER is not able to imply the hidden semantic meanings between the words. It only count the occurences of positive and negative words based on what are defined in the VADER lexicon library.

# %%
print(ow2_5topics.iloc[31]['review'])
print(ow2_5topics.iloc[31]['compound_recommended'])
# Out:
# A "complete rehaul" of OW1 and it plays exactly the same except you have to spend $60AUD every 8 weeks to have the "opportunity" to obtain the items you want + two otherwise unobtainable skins. Capitalism at its finest.
# 1.0

# %%
ow2_5topics.iloc[13]['voted_up'] = 0.0
# Out:
# /var/folders/1h/p6khwwdj4nx6frsjpgvf3h9r0000gn/T/ipykernel_50819/1654948400.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ow2_5topics.iloc[13]['voted_up'] = 0.0

# %%
scores = analyzer.polarity_scores('Dogshit servers, audio bugs since s1. Instead of using the money to make the game better, Respawn uses the money to flush out more skin recolors to make more money, classic EA moves I guess.')

print(scores)
# Out:
# {'neg': 0.122, 'neu': 0.807, 'pos': 0.071, 'compound': -0.4767}

# %%
ow2_5topics.iloc[90]['compound_recommended']
# Out:
# 0.0

# %%
from sklearn.metrics import accuracy_score

accuracy_score(ow2_5topics['voted_up'], ow2_5topics['compound_recommended'])
# Out:
# 0.6456140350877193

# %% [markdown]
# Discussion
# Review 3: You open the game and finish your 3000 word essay that's due tomorrow while it loads you into the main menu. You pray they fed the server hamsters today as you queue for a game. You pick Octane cause you like running around fast, not cause he's on drugs. Your teammates pick Caustic and Wraith. It's another TTV Wraith. The champion squad is a pred and 2 master players. The game begins and your caustic spends all game on his own trapping buildings, while you run around juiced up looking for loot and killing anyone in your way. You get jumped by a squad because footstep audio doesn't exist and you couldn't hear them coming. TTV Wraith goes down. You clutch a 1v3 because mastiff is balanced. Meanwhile, your Caustic is setting up traps outside the zone. You collect your Wraith's banner and try to respawn them but they leave with 0.2s left on the timer. You're in awe that this one stayed that long. Someone sees you next to the respawn beacon and kills you. They then immediately get 3rd partied while a far off 4th squad member misses all his kraber shots on them. The predator player shows up out of nowhere and wipes everyone in one sweep, dropping another 4k 20 bomb in the process. Your caustic dies to zone. You're back in the main menu and a random level 500 is waiting there for you in your party. They complain about not having heirlooms despite playing since season 1 but the dude that started last week has 2. You queue for another game. You get disconnected because two server hamsters passed out from hunger. Code: leaf. You wait to load back into the main menu and queue once more, cause you know it's worth going through it all again just to take another glance at Loba's thick ass.\n\n10/10. Def recommend"
#
# Explanation The review is classified as a negative review when it should be positive. Reasons given:-
#
# It contains a mix of both positive and negative sentiments, but VADER might classify it as negative due to the prevalence of certain phrases and context. Words and phrases like "you couldn't hear them coming," "your Caustic is setting up traps outside the zone," "you get disconnected," and "server hamsters passed out from hunger" all carry negative connotations and may influence VADER’s sentiment scoring.
# The overall narrative starts with complaints and frustrations, which may set a negative tone for the analysis, even if the conclusion is positive. Sentiment analysis algorithms often focus on the overall tone and frequency of negative versus positive expressions in the text.

# %%
ow2_5topics.head()
# Out:
#                                               review timestamp_updated  \
# 0  This really is a game that is not good for you...        2023-10-16
# 1  got almost 900 hours, its a good game but want...        2024-07-10
# 2  The skins are good.\nThey cost too much. \n\nB...        2024-06-21
# 3  this game is horrible i load into any round an...        2024-01-08
# 4  I bought the game and after its transition to ...        2023-08-21
#
#    voted_up  comment_count     author.steamid  author.playtime_at_review  \
# 0       0.0              8  76561198426916437                   5.066667
# 1       0.0              0  76561198413080751                  86.166667
# 2       0.0              1  76561198101681894                 355.000000
# 3       0.0              0  76561198304704423                  25.266667
# 4       1.0              1  76561198189115163                  31.133333
#
#          Topic                                     Representation  \
# 0  Matchmaking  ['matchmaking', 'worst matchmaking', 'worst', ...
# 1    Expensive  ['skin', 'price', 'buy skin', 'expensive', 'we...
# 2    Expensive  ['skin', 'price', 'buy skin', 'expensive', 'we...
# 3       Sombra  ['sombra', 'remove sombra', 'sombra remove som...
# 4    Expensive  ['skin', 'price', 'buy skin', 'expensive', 'we...
#
#                                  Representative_Docs  \
# 0  ['worst matchmaking ame', 'worst matchmaking',...
# 1  ['change color old skin charge dollars also ma...
# 2  ['change color old skin charge dollars also ma...
# 3    ['sombra hate', 'sombra still', 'sombra still']
# 4  ['change color old skin charge dollars also ma...
#
#                                          Top_n_words  Probability  \
# 0  matchmaking - worst matchmaking - worst - matc...     1.000000
# 1  skin - price - buy skin - expensive - weapon s...     0.230906
# 2  skin - price - buy skin - expensive - weapon s...     0.226672
# 3  sombra - remove sombra - sombra remove sombra ...     0.241103
# 4  skin - price - buy skin - expensive - weapon s...     0.448012
#
#    Representative_document  compound_sentiment  compound_recommended
# 0                    False             -0.3412                   0.0
# 1                    False              0.6111                   1.0
# 2                    False              0.2500                   1.0
# 3                    False              0.3612                   1.0
# 4                    False              0.8172                   1.0

# %%
ow2_5topics.to_csv('./ow2_tableau.csv')
